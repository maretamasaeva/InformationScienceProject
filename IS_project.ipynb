# %%
import os
import sqlite3

# %%
conn = sqlite3.connect('stcv.sqlite')

# %%
c = conn.cursor()

# %%
query = """
SELECT DISTINCT
    title.cloi as identifier,
    COUNT(title.cloi) as id_count,
    author_vw as author_standardized,
    author_zvwr as author_original,
    author_zbd as author_dates,
    corporateauthor_nm as corporateauthor_standardized,
    corporateauthor_zvwr as corporateauthor_original,
    title_ti as title_title
    FROM title
LEFT JOIN author on author.cloi = title.cloi
LEFT JOIN collation on collation.cloi = title.cloi
LEFT JOIN corporateauthor on corporateauthor.cloi = title.cloi
LEFT JOIN edition on edition.cloi = title.cloi
LEFT JOIN impressum on impressum.cloi = title.cloi
LEFT JOIN language on language.cloi = title.cloi
LEFT JOIN number on number.cloi = title.cloi
GROUP BY identifier
HAVING ID_COUNT=2
LIMIT 100
"""

# %%
c.execute(query)

# %%
data = [row for row in c.fetchall()]
for row in data:
    print(row)
# Out:
# ('c:stcv:12854444', 2, 'Ernst, Simon-Pierre', 'S.P. Ernst', '1744-1817', None, None, 'Apologie des ministres du culte, qui ont prêté la déclaration exigée par la loi du 7 vendém. an 4. contre les critiques de mm. Dédoyar & Vanhoren, les Motifs de Malines & autres brochures')
# ('c:stcv:12854501', 2, 'Ernst, Simon-Pierre', 'S.P. Ernst', '1744-1817', None, None, 'Observations sur la déclaration exigée des ministres des cultes, en vertu de la loi du 7 vendémiaire, an 4')
# ('c:stcv:12854549', 2, 'Gisbert, Blaise', 'Gisbert', '1657-1731', None, None, "l'Eloquence chrétienne dans l'idée et dans la pratique")
# ('c:stcv:12854587', 2, None, None, None, None, None, 'Verscheyde leeringen en exempelen der oude vaders')
# ('c:stcv:12854599', 2, None, None, None, None, None, 'Godtvruchtige leeringen en gebeden voor de eerste communie')
# ('c:stcv:12857052', 2, 'Courvoisier, Jean-Jacques', 'Iean Iacques Couruoisier', '', None, None, "Le prince immortel tiré sur la vie & la fin glorieuse de son altesse royale don Ferdinand d'Avstriche")
# ('c:stcv:12857069', 2, 'Choquet, François Hyacinthe', 'Franciscus Hyacinthus Choqvetius', '1581-1645', None, None, 'Trivmphvs rosarii a sede apostolica decretvs sodalitati B. virginis Mariæ')
# ('c:stcv:12857131', 2, 'Lancelottus, Lucas', 'Lvcas Lancelottus', '', None, None, 'In statvas antiqvitatis et elegantias Arvndellianas cento Maronianvs')
# ('c:stcv:12857158', 2, None, None, None, None, None, 'Inde[x] librorvm qvi in typographia Plantiniana excvsi venales nvnc exstant')
# ('c:stcv:12857275', 2, 'Pauwels, Nicolaus', 'Nicolaus Pauwels', '-1713', None, None, 'Theologiæ practicæ in qua de actibus humanis [...] agitur [...] pars quarta')
# ('c:stcv:12857374', 2, 'Noot, van der, Henri Charles Nicolas', 'H.C.N. van der Noot', '1731-1827', None, None, 'Gedenk-stuk op de geregtigheden der Brabanders, en de beledigingen, die tegen de zelve geschied zyn uyt den naem van S.M. den keyzer en koning, sedert eenige jaeren')
# ('c:stcv:12857912', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'David regivs psaltes descriptvs')
# ('c:stcv:12857923', 2, 'member of the fraternity of the Holy Cross [Hoboken]', 'N.N. cofrade de la misma cofradia', '', None, None, 'Librito de la cofradia de la s.ta Crvz de Hoboqve de la dioceis de Anberes')
# ('c:stcv:12858124', 2, 'M.Æ.V.D.V.', 'M.Æ.V.D.V.', '', None, None, 'Het vereerlykt Oostenryk, in den oorlog tegen den koning van Pruyssen')
# ('c:stcv:12858392', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Tobias morali doctrinâ illustratus [...] ex posthumis libellis quartus. Monachii M.DC.XLI.')
# ('c:stcv:12858408', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Aloe amari sed salubris succi ieivnivm')
# ('c:stcv:12858413', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Rosæ selectissimarum virtutum, quas Dei mater orbi exhibet, pars II.')
# ('c:stcv:12858468', 2, 'Cicero, Marcus Tullius', 'M. Tvllius Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'Orationvm volvmen II.')
# ('c:stcv:12858494', 2, None, None, None, None, None, "Nouvvelle chronicqve contenant les choses plus memorables advenues en ces Pays-bas, depuis l'an 1500. jusques à l'an present")
# ('c:stcv:12858622', 2, 'Busaeus, Joannes', 'Ioannes Bvsæus', '1547-1611', None, None, 'Enchiridion piarvm meditationvm in omnes dominicas')
# ('c:stcv:12858690', 2, 'Andries, Judocus', 'Iudocus Andries', '1588-1658', None, None, 'Pvrgatorivm catholicè assertum')
# ('c:stcv:12858729', 2, 'Malvezzi, Virgilio', 'Virgilio Malvezzi', '1599-1653', None, None, "Svccessi principali della monarchia di Spagna nell'anno M.DC.XXXIX.")
# ('c:stcv:12858795', 2, 'Caramuel de Lobkowitz, Juan', 'Ioannes Caramvel Lobkovvitz', '1606-1682', None, None, 'Solis et artis adulteria')
# ('c:stcv:12859250', 2, 'Linden, van der, Jan', 'Ian vander Linden', '-1638', None, None, 'Heerlycke ende gheluckighe reyse na het Heyligh Landt ende de stadt van Jerusalem [...]. Het eerste deel')
# ('c:stcv:12859427', 2, 'Faber, Matthias', 'Faber, Matthias', '1587-1653', None, None, 'Conciones funebres et nuptiales')
# ('c:stcv:12859712', 2, 'Pomey, François', 'Franciscus Pomey', '1618-1673', None, None, 'Novus candidatus rhetoricæ')
# ('c:stcv:12859754', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta')
# ('c:stcv:12859820', 2, 'Saavedra de Fajardo, Diego', 'Diego Saavedra Faxardo', '-1648', None, None, 'Corona gothica, castellana, y avstriaca')
# ('c:stcv:12859871', 2, 'Limon, de, Geoffroi', 'de Limon', '', None, None, 'La vie et le martyre de Louis XVI [...] immolé le 21 janvier 1793; avec un examen du décret régicide')
# ('c:stcv:12859905', 2, None, None, None, None, None, "Traité touchant la suppression de la mendicité et l'administration des pauvres dans la ville d'Anvers")
# ('c:stcv:12859931', 2, None, None, None, None, None, 'Recueil de loix concernant le régime hypothécaire a les déclarations foncieres')
# ('c:stcv:12860028', 2, 'Becanus, Martin', 'Martinus Becanus', '1563-1624', None, None, 'Analogia Veteris ac Novi Testamenti')
# ('c:stcv:12860136', 2, 'Balbany, André Christophe', 'Balbany, André Christophe', '1723-[1788-]', None, None, 'Appèl a la raison des écrits et libelles publiés par la passion, contre les jésuites de France')
# ('c:stcv:12860498', 2, None, None, None, None, None, 'Copy van een seecker boecxken dat onlanckx is vvt ghegaen, trackterende van een miraeckel oft spectakel, dat te Amsterdam geschiet is')
# ('c:stcv:12860697', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta')
# ('c:stcv:12860711', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta')
# ('c:stcv:12860736', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta')
# ('c:stcv:12861541', 2, 'Ovid', 'Pvb. Ovidius Naso', '43 ante Chr.-18', None, None, 'Fastorvm libri VI. Tristivm libri V. De ponto libri IV. In Ibin ad Liviam')
# ('c:stcv:12861606', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta')
# ('c:stcv:12861734', 2, 'Cicero, Marcus Tullius', 'M. T. Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'De officiis libri tres. Cato major, vel de senectute. Lælius, vel de amicitia. Paradoxa stoicorum sex. Somnium Scipionis')
# ('c:stcv:12861760', 2, 'Cicero, Marcus Tullius', 'M. T. Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'De officiis libri tres. Cato major, vel de senectute. Lælius, vel de amicitia. Paradoxa stoicorum sex. Somnium Scipionis')
# ('c:stcv:12861798', 2, 'Seneca [Younger]', 'L. Annæus Seneca', 'Ca. 4 n.Chr.-65 n.Chr.', None, None, 'Flores, ex operibus illius singulari judicio selecti')
# ('c:stcv:12861813', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta')
# ('c:stcv:12862032', 2, None, None, None, None, None, 'Les provinciaux détrompés. Comédie en trois actes')
# ('c:stcv:12862035', 2, None, None, None, None, None, "l'Heureuse pêche, comédie pour les ombres a scenes changeantes")
# ('c:stcv:12862038', 2, "Allainval, d', Léonor-Jean-Christine Soulas", "d'Allainval", '1700-1753', None, None, "l'Ecole des bourgeois, comédie en trois actes")
# ('c:stcv:12862053', 2, 'Favart, Charles-Simon', 'Favart', '1710-1792', None, None, 'La rosiere de Salenci, comédie en trois actes')
# ('c:stcv:12862058', 2, 'Darcis', 'Darcis', '', None, None, 'Le bal masqué, opéra-comique en un acte')
# ('c:stcv:12862118', 2, 'Beaumarchais, de, Pierre Augustin Caron', 'de Beaumarchais', '1732-1799', None, None, 'Les deux amis, ou Le négociant de Lyon, drame en cinq actes en prose')
# ('c:stcv:12862125', 2, 'Billardon de Sauvigny, Louis Edmé', 'de Sauvigny', '1736-1812', None, None, 'Le persifleur, comédie en trois actes et en vers')
# ('c:stcv:12862153', 2, 'Barthe, Nicolas Thomas', 'Barthe', '1734-1785', None, None, 'La mere jalouse, comédie en trois actes et en vers')
# ('c:stcv:12862168', 2, 'Armand', 'Armand', '1699-1765', None, None, 'Le cri de la nature, comédie en vers et en un acte')
# ('c:stcv:12863004', 2, 'Sylvius, Franciscus', 'Franciscus Silvius', '', None, None, 'Commentarii in totam primam partem S. Thom. Aqvinatis')
# ('c:stcv:12865436', 2, 'Sylvius, Franciscus', 'Franciscus Sylvius', '', None, None, 'Opera omnia, sex tomis comprehensa')
# ('c:stcv:12865677', 2, 'Cygne, du, Martin', 'Martinus du Cygne', '1619-1669', None, None, 'Ars rhetorica')
# ('c:stcv:12865828', 2, 'Polman, Joannes', 'Joannes Polmannus', '', None, None, 'Breviarium theologicum continens definitiones, descriptiones, & explicationes terminorum theologicorum')
# ('c:stcv:12866841', 2, 'Bauvin, Jean-Grégoire', 'Bauvin', '', None, None, 'Les chérusques, tragédie')
# ('c:stcv:12866854', 2, 'Rousseau, Jean-Jacques', 'J.J. Rousseau', '1712-1778', None, None, 'Pygmalion, scene lyrique')
# ('c:stcv:12866862', 2, None, None, None, None, None, "l'Orphelin anglais, drame, en trois actes, en prose")
# ('c:stcv:12866867', 2, None, None, None, None, None, 'Bélisaire, drame en cinq actes et en vers')
# ('c:stcv:12866905', 2, 'Favart, Charles-Simon', 'Favart, Charles-Simon', '1710-1792', None, None, "l'Amant déguisé ou Le jardinier supposé, comédie en un acte")
# ('c:stcv:12866912', 2, 'Goldoni, Carlo', 'Goldoni', '1707-1793', None, None, 'Le bourru bienfaisant, comédie en trois actes et en prose')
# ('c:stcv:12866920', 2, 'Ribadière, de la', 'de la Ribardiere', '', None, None, 'Les aveux indiscrets, opera comique')
# ('c:stcv:12866939', 2, None, None, None, None, None, 'Le maître en droit, opera-comique en deux actes')
# ('c:stcv:12867300', 2, 'Moens, Adrianus', 'Adrianus Moens', '', None, None, 'Enchiridion religiosorvm')
# ('c:stcv:12867792', 2, 'Woestwinckel, Petrus', 'Woestwinckel, Petrus', '1595-1673', None, None, 'Mariæ virginis [...] excellentia, potentia, misericordia; compendio exposita')
# ('c:stcv:12867804', 2, 'Moens, Adrianus', 'Adr. Moens', '', None, None, 'Privilegia a variis pontificibvs concessa ac demvm a Clemente VIII. confirmata pro fratribvs III. ord. S. Francisci de poenit. qvi svnt de capitvlo Zepperensi')
# ('c:stcv:12867845', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Aloe amari sed salubris succi ieivnivm')
# ('c:stcv:12867878', 2, 'F.C.A.M.R.', 'F.C.A.M.R.', '', None, None, 'Clarissimo viro D. Francisco Lams I.V.L. urbis Antuerpien. electo syndico')
# ('c:stcv:12867885', 2, 'Bardonville', 'Bardonville', '', None, None, 'Le Confiteor dv chancelier av temps de Pasqves')
# ('c:stcv:12867907', 2, 'More, Henry', 'Henricvs Morvs', '1586-1661', None, None, 'Vita et doctrina Christi domini')
# ('c:stcv:12867929', 2, 'Kempis, a, Joannes Wilhelmus', 'Ioannes VVilhelmus a Kempis', '', None, None, 'Praxis medica de præservatione & curatione morbi articularis & calculi')
# ('c:stcv:12867974', 2, None, None, None, None, None, "La desiree paix entra sa majesté catholicque d'-Espagne, & les seigneurs estats des provinces unies d'Hollande, &c. Faite & signée à Munster le huictiesme de ianvier 1647")
# ('c:stcv:12868566', 2, None, None, None, None, None, 'Epinicia sanctis martyribvs victoribvs trivmphatoribvs, quorum sacra corpora [...] in thronis [...] templi domus professæ societatis Iesu Antuerpiæ fuêre reposita')
# ('c:stcv:12868625', 2, 'Rivius, Joannes', 'Ioannes Rivius', '1599-1665', None, None, 'S. Thomas a Villanova [...] a S.D.N. Alexandro papa VII. in divorvm nvmervm relatvs anno M.DC.LVIII.')
# ('c:stcv:12868640', 2, 'Henschenius, Godefridus', 'Godefridus Henschenius', '1601-1681', None, None, 'De episcopatv Traiectensi [...] diatriba')
# ('c:stcv:12868663', 2, 'Alexander VII [Pope]', 'Philomathus', '1599-1667', None, None, 'Mvsæ ivveniles')
# ('c:stcv:12868736', 2, 'Alvarez, Manuel', 'Emmanvel Alvarus', '1526-1583', None, None, 'Grammatica sive Institvtionvm lingvæ Latinæ liber secvndvs')
# ('c:stcv:12868749', 2, 'Alvarez, Manuel', 'Emmanvel Alvarus', '1526-1583', None, None, 'Syntaxis sive Institvtionvm lingvæ Latinæ liber tertivs. In usum studiosorum societatis Iesv')
# ('c:stcv:12868755', 2, 'Alvarez, Manuel', 'Emmanvel Alvarus', '1526-1583', None, None, 'Prosodia sive Institvtionvm lingvæ Latinæ liber qvartvs. In usum studiosorum societatis Iesv')
# ('c:stcv:12868758', 2, 'Soarez, Cyprianus', 'Cyprianus Soarez', '1524-1593', None, None, 'De arte rhetorica libri tres')
# ('c:stcv:12868994', 2, 'Torsellini, Horatius', 'Horatius Tvrsellinus', '1544-1599', None, None, 'De particvlis Latinæ orationis')
# ('c:stcv:12869036', 2, 'Fernandez, Marcos', 'Marcos Fernandez', '', None, None, 'Olla podrida a la Española, compuesta i façonada en la description de Munster en Vesfalia con salsa Sarracena i Africana')
# ('c:stcv:12869148', 2, 'Urban VIII [Pope]', 'Urbanus papa VIII', '1568-1644', None, None, 'Bulla [...] pro clero & religiosis missionariis ad propagandam fidem. In fœderatis Belgij provinciis')
# ('c:stcv:12869229', 2, 'Cicero, Marcus Tullius', 'M. Tvllius Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'Ad Qvintvm fratrem de oratore dialogi tres')
# ('c:stcv:12869264', 2, 'Stanihurstus, Guilielmus', 'Guilielmus Stanihurstus', '1601-1663', None, None, 'Dei immortalis in corpore mortali patientis historia')
# ('c:stcv:12869479', 2, 'Favart, Charles-Simon', 'Favat [!]', '1710-1792', None, None, "l'Anglois a Bordeaux; comedie en un acte et en vers libres")
# ('c:stcv:12869497', 2, 'Favart, Charles-Simon', 'Favart, Charles-Simon', '1710-1792', None, None, 'La fausse duègne ou Le jaloux corrigé par force, opera-comique en deux actes')
# ('c:stcv:12869500', 2, None, None, None, None, None, "Il étoit tems ou l'Ecuyer temeraire, petit opera-comique en un acte")
# ('c:stcv:12869588', 2, 'Sedaine, Michel Jean', 'Sedaine, Michel Jean', '1719-1797', None, None, 'Rose et Colas, comédie en un acte')
# ('c:stcv:12869609', 2, 'Romagnesi, Jean-Antoine', 'Romagnesi', '1690-1742', None, None, 'Samson')
# ('c:stcv:12869812', 2, 'Puteanus, Erycius', 'E. Pvteanus', '1574-1646', None, None, 'De indvciis avt pace Belgarvm dissertationes variæ')
# ('c:stcv:12869845', 2, 'Tamburino, Thomas', 'Thomas Tambvrinus', '', None, None, 'De sacrificio missæ expedite celebrando libri tres')
# ('c:stcv:12869872', 2, 'P.N.S.N.', 'P.N.S.N.', '', None, None, 'Disceptatio et justa defensio septem controversiarum [...] super collatione verbo scriptoque habitâ inter duos patres Embricenses è societate Iesu, & duos ministros reformatæ religionis. Adversus D. Petrum Cabeljavium, ministrum Leidensem')
# ('c:stcv:12869899', 2, 'Cambry, de, P.', 'P. de Cambry', '', None, None, "Abbregé de la vie de dame Ienne de Cambry, premierement religieuse de l'ordre de S. Augustin à Tournay, & depuis sœur Ienne Marie de la Presentation recluse lez Lille")
# ('c:stcv:12869970', 2, 'Urban VIII [Pope]', 'Vrbanus [...] papa VIII', '1568-1644', None, None, 'Confirmatio constitutionum Pij papæ V. & Gregorij XIII. prohibentium quasdam theologorum sententias, & opiniones. Nec non prohibitio libri, cui titulus, Augustinus, Cornelij Iansenij [...] excusi Lovanij, typis Iacobi Zegeri, anno 1640.')
# ('c:stcv:12869997', 2, 'Chifflet, Laurent', 'Lavrent Chiflet', '1598-1658', None, None, "Essay d'vne parfaite grammaire de la langve françoise")
# ('c:stcv:12870045', 2, 'Cicero, Marcus Tullius', 'M. T. Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'Celebriores sententiæ, apophthegmata et similitvdines ex operibus M.T. Ciceronis collectæ')
# ('c:stcv:12870054', 2, None, None, None, None, None, 'Catechisme ov Doctrine chrestienne divisée en cinq parties, et quarante & vne leçons')
# ('c:stcv:12870121', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Rhetorica cælestis seu Attente precandi scientia')

# %%
data
# Out:
# [('c:stcv:12854444',
#   2,
#   'Ernst, Simon-Pierre',
#   'S.P. Ernst',
#   '1744-1817',
#   None,
#   None,
#   'Apologie des ministres du culte, qui ont prêté la déclaration exigée par la loi du 7 vendém. an 4. contre les critiques de mm. Dédoyar & Vanhoren, les Motifs de Malines & autres brochures'),
#  ('c:stcv:12854501',
#   2,
#   'Ernst, Simon-Pierre',
#   'S.P. Ernst',
#   '1744-1817',
#   None,
#   None,
#   'Observations sur la déclaration exigée des ministres des cultes, en vertu de la loi du 7 vendémiaire, an 4'),
#  ('c:stcv:12854549',
#   2,
#   'Gisbert, Blaise',
#   'Gisbert',
#   '1657-1731',
#   None,
#   None,
#   "l'Eloquence chrétienne dans l'idée et dans la pratique"),
#  ('c:stcv:12854587',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Verscheyde leeringen en exempelen der oude vaders'),
#  ('c:stcv:12854599',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Godtvruchtige leeringen en gebeden voor de eerste communie'),
#  ('c:stcv:12857052',
#   2,
#   'Courvoisier, Jean-Jacques',
#   'Iean Iacques Couruoisier',
#   '',
#   None,
#   None,
#   "Le prince immortel tiré sur la vie & la fin glorieuse de son altesse royale don Ferdinand d'Avstriche"),
#  ('c:stcv:12857069',
#   2,
#   'Choquet, François Hyacinthe',
#   'Franciscus Hyacinthus Choqvetius',
#   '1581-1645',
#   None,
#   None,
#   'Trivmphvs rosarii a sede apostolica decretvs sodalitati B. virginis Mariæ'),
#  ('c:stcv:12857131',
#   2,
#   'Lancelottus, Lucas',
#   'Lvcas Lancelottus',
#   '',
#   None,
#   None,
#   'In statvas antiqvitatis et elegantias Arvndellianas cento Maronianvs'),
#  ('c:stcv:12857158',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Inde[x] librorvm qvi in typographia Plantiniana excvsi venales nvnc exstant'),
#  ('c:stcv:12857275',
#   2,
#   'Pauwels, Nicolaus',
#   'Nicolaus Pauwels',
#   '-1713',
#   None,
#   None,
#   'Theologiæ practicæ in qua de actibus humanis [...] agitur [...] pars quarta'),
#  ('c:stcv:12857374',
#   2,
#   'Noot, van der, Henri Charles Nicolas',
#   'H.C.N. van der Noot',
#   '1731-1827',
#   None,
#   None,
#   'Gedenk-stuk op de geregtigheden der Brabanders, en de beledigingen, die tegen de zelve geschied zyn uyt den naem van S.M. den keyzer en koning, sedert eenige jaeren'),
#  ('c:stcv:12857912',
#   2,
#   'Drexelius, Hieremias',
#   'Hieremias Drexelius',
#   '1581-1638',
#   None,
#   None,
#   'David regivs psaltes descriptvs'),
#  ('c:stcv:12857923',
#   2,
#   'member of the fraternity of the Holy Cross [Hoboken]',
#   'N.N. cofrade de la misma cofradia',
#   '',
#   None,
#   None,
#   'Librito de la cofradia de la s.ta Crvz de Hoboqve de la dioceis de Anberes'),
#  ('c:stcv:12858124',
#   2,
#   'M.Æ.V.D.V.',
#   'M.Æ.V.D.V.',
#   '',
#   None,
#   None,
#   'Het vereerlykt Oostenryk, in den oorlog tegen den koning van Pruyssen'),
#  ('c:stcv:12858392',
#   2,
#   'Drexelius, Hieremias',
#   'Hieremias Drexelius',
#   '1581-1638',
#   None,
#   None,
#   'Tobias morali doctrinâ illustratus [...] ex posthumis libellis quartus. Monachii M.DC.XLI.'),
#  ('c:stcv:12858408',
#   2,
#   'Drexelius, Hieremias',
#   'Hieremias Drexelius',
#   '1581-1638',
#   None,
#   None,
#   'Aloe amari sed salubris succi ieivnivm'),
#  ('c:stcv:12858413',
#   2,
#   'Drexelius, Hieremias',
#   'Hieremias Drexelius',
#   '1581-1638',
#   None,
#   None,
#   'Rosæ selectissimarum virtutum, quas Dei mater orbi exhibet, pars II.'),
#  ('c:stcv:12858468',
#   2,
#   'Cicero, Marcus Tullius',
#   'M. Tvllius Cicero',
#   '106 ante Chr.-43 ante Chr.',
#   None,
#   None,
#   'Orationvm volvmen II.'),
#  ('c:stcv:12858494',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   "Nouvvelle chronicqve contenant les choses plus memorables advenues en ces Pays-bas, depuis l'an 1500. jusques à l'an present"),
#  ('c:stcv:12858622',
#   2,
#   'Busaeus, Joannes',
#   'Ioannes Bvsæus',
#   '1547-1611',
#   None,
#   None,
#   'Enchiridion piarvm meditationvm in omnes dominicas'),
#  ('c:stcv:12858690',
#   2,
#   'Andries, Judocus',
#   'Iudocus Andries',
#   '1588-1658',
#   None,
#   None,
#   'Pvrgatorivm catholicè assertum'),
#  ('c:stcv:12858729',
#   2,
#   'Malvezzi, Virgilio',
#   'Virgilio Malvezzi',
#   '1599-1653',
#   None,
#   None,
#   "Svccessi principali della monarchia di Spagna nell'anno M.DC.XXXIX."),
#  ('c:stcv:12858795',
#   2,
#   'Caramuel de Lobkowitz, Juan',
#   'Ioannes Caramvel Lobkovvitz',
#   '1606-1682',
#   None,
#   None,
#   'Solis et artis adulteria'),
#  ('c:stcv:12859250',
#   2,
#   'Linden, van der, Jan',
#   'Ian vander Linden',
#   '-1638',
#   None,
#   None,
#   'Heerlycke ende gheluckighe reyse na het Heyligh Landt ende de stadt van Jerusalem [...]. Het eerste deel'),
#  ('c:stcv:12859427',
#   2,
#   'Faber, Matthias',
#   'Faber, Matthias',
#   '1587-1653',
#   None,
#   None,
#   'Conciones funebres et nuptiales'),
#  ('c:stcv:12859712',
#   2,
#   'Pomey, François',
#   'Franciscus Pomey',
#   '1618-1673',
#   None,
#   None,
#   'Novus candidatus rhetoricæ'),
#  ('c:stcv:12859754',
#   2,
#   'Chifflet, Philippe',
#   'Philippus Chiffletius',
#   '1597-1657',
#   'Council of Trent',
#   'Concilium Tridentinum',
#   'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta'),
#  ('c:stcv:12859820',
#   2,
#   'Saavedra de Fajardo, Diego',
#   'Diego Saavedra Faxardo',
#   '-1648',
#   None,
#   None,
#   'Corona gothica, castellana, y avstriaca'),
#  ('c:stcv:12859871',
#   2,
#   'Limon, de, Geoffroi',
#   'de Limon',
#   '',
#   None,
#   None,
#   'La vie et le martyre de Louis XVI [...] immolé le 21 janvier 1793; avec un examen du décret régicide'),
#  ('c:stcv:12859905',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   "Traité touchant la suppression de la mendicité et l'administration des pauvres dans la ville d'Anvers"),
#  ('c:stcv:12859931',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Recueil de loix concernant le régime hypothécaire a les déclarations foncieres'),
#  ('c:stcv:12860028',
#   2,
#   'Becanus, Martin',
#   'Martinus Becanus',
#   '1563-1624',
#   None,
#   None,
#   'Analogia Veteris ac Novi Testamenti'),
#  ('c:stcv:12860136',
#   2,
#   'Balbany, André Christophe',
#   'Balbany, André Christophe',
#   '1723-[1788-]',
#   None,
#   None,
#   'Appèl a la raison des écrits et libelles publiés par la passion, contre les jésuites de France'),
#  ('c:stcv:12860498',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Copy van een seecker boecxken dat onlanckx is vvt ghegaen, trackterende van een miraeckel oft spectakel, dat te Amsterdam geschiet is'),
#  ('c:stcv:12860697',
#   2,
#   'Chifflet, Philippe',
#   'Philippus Chiffletius',
#   '1597-1657',
#   'Council of Trent',
#   'Concilium Tridentinum',
#   'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta'),
#  ('c:stcv:12860711',
#   2,
#   'Chifflet, Philippe',
#   'Philippus Chiffletius',
#   '1597-1657',
#   'Council of Trent',
#   'Concilium Tridentinum',
#   'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta'),
#  ('c:stcv:12860736',
#   2,
#   'Chifflet, Philippe',
#   'Philippus Chiffletius',
#   '1597-1657',
#   'Council of Trent',
#   'Concilium Tridentinum',
#   'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta'),
#  ('c:stcv:12861541',
#   2,
#   'Ovid',
#   'Pvb. Ovidius Naso',
#   '43 ante Chr.-18',
#   None,
#   None,
#   'Fastorvm libri VI. Tristivm libri V. De ponto libri IV. In Ibin ad Liviam'),
#  ('c:stcv:12861606',
#   2,
#   'Chifflet, Philippe',
#   'Philippus Chiffletius',
#   '1597-1657',
#   'Council of Trent',
#   'Concilium Tridentinum',
#   'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta'),
#  ('c:stcv:12861734',
#   2,
#   'Cicero, Marcus Tullius',
#   'M. T. Cicero',
#   '106 ante Chr.-43 ante Chr.',
#   None,
#   None,
#   'De officiis libri tres. Cato major, vel de senectute. Lælius, vel de amicitia. Paradoxa stoicorum sex. Somnium Scipionis'),
#  ('c:stcv:12861760',
#   2,
#   'Cicero, Marcus Tullius',
#   'M. T. Cicero',
#   '106 ante Chr.-43 ante Chr.',
#   None,
#   None,
#   'De officiis libri tres. Cato major, vel de senectute. Lælius, vel de amicitia. Paradoxa stoicorum sex. Somnium Scipionis'),
#  ('c:stcv:12861798',
#   2,
#   'Seneca [Younger]',
#   'L. Annæus Seneca',
#   'Ca. 4 n.Chr.-65 n.Chr.',
#   None,
#   None,
#   'Flores, ex operibus illius singulari judicio selecti'),
#  ('c:stcv:12861813',
#   2,
#   'Chifflet, Philippe',
#   'Philippus Chiffletius',
#   '1597-1657',
#   'Council of Trent',
#   'Concilium Tridentinum',
#   'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta'),
#  ('c:stcv:12862032',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Les provinciaux détrompés. Comédie en trois actes'),
#  ('c:stcv:12862035',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   "l'Heureuse pêche, comédie pour les ombres a scenes changeantes"),
#  ('c:stcv:12862038',
#   2,
#   "Allainval, d', Léonor-Jean-Christine Soulas",
#   "d'Allainval",
#   '1700-1753',
#   None,
#   None,
#   "l'Ecole des bourgeois, comédie en trois actes"),
#  ('c:stcv:12862053',
#   2,
#   'Favart, Charles-Simon',
#   'Favart',
#   '1710-1792',
#   None,
#   None,
#   'La rosiere de Salenci, comédie en trois actes'),
#  ('c:stcv:12862058',
#   2,
#   'Darcis',
#   'Darcis',
#   '',
#   None,
#   None,
#   'Le bal masqué, opéra-comique en un acte'),
#  ('c:stcv:12862118',
#   2,
#   'Beaumarchais, de, Pierre Augustin Caron',
#   'de Beaumarchais',
#   '1732-1799',
#   None,
#   None,
#   'Les deux amis, ou Le négociant de Lyon, drame en cinq actes en prose'),
#  ('c:stcv:12862125',
#   2,
#   'Billardon de Sauvigny, Louis Edmé',
#   'de Sauvigny',
#   '1736-1812',
#   None,
#   None,
#   'Le persifleur, comédie en trois actes et en vers'),
#  ('c:stcv:12862153',
#   2,
#   'Barthe, Nicolas Thomas',
#   'Barthe',
#   '1734-1785',
#   None,
#   None,
#   'La mere jalouse, comédie en trois actes et en vers'),
#  ('c:stcv:12862168',
#   2,
#   'Armand',
#   'Armand',
#   '1699-1765',
#   None,
#   None,
#   'Le cri de la nature, comédie en vers et en un acte'),
#  ('c:stcv:12863004',
#   2,
#   'Sylvius, Franciscus',
#   'Franciscus Silvius',
#   '',
#   None,
#   None,
#   'Commentarii in totam primam partem S. Thom. Aqvinatis'),
#  ('c:stcv:12865436',
#   2,
#   'Sylvius, Franciscus',
#   'Franciscus Sylvius',
#   '',
#   None,
#   None,
#   'Opera omnia, sex tomis comprehensa'),
#  ('c:stcv:12865677',
#   2,
#   'Cygne, du, Martin',
#   'Martinus du Cygne',
#   '1619-1669',
#   None,
#   None,
#   'Ars rhetorica'),
#  ('c:stcv:12865828',
#   2,
#   'Polman, Joannes',
#   'Joannes Polmannus',
#   '',
#   None,
#   None,
#   'Breviarium theologicum continens definitiones, descriptiones, & explicationes terminorum theologicorum'),
#  ('c:stcv:12866841',
#   2,
#   'Bauvin, Jean-Grégoire',
#   'Bauvin',
#   '',
#   None,
#   None,
#   'Les chérusques, tragédie'),
#  ('c:stcv:12866854',
#   2,
#   'Rousseau, Jean-Jacques',
#   'J.J. Rousseau',
#   '1712-1778',
#   None,
#   None,
#   'Pygmalion, scene lyrique'),
#  ('c:stcv:12866862',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   "l'Orphelin anglais, drame, en trois actes, en prose"),
#  ('c:stcv:12866867',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Bélisaire, drame en cinq actes et en vers'),
#  ('c:stcv:12866905',
#   2,
#   'Favart, Charles-Simon',
#   'Favart, Charles-Simon',
#   '1710-1792',
#   None,
#   None,
#   "l'Amant déguisé ou Le jardinier supposé, comédie en un acte"),
#  ('c:stcv:12866912',
#   2,
#   'Goldoni, Carlo',
#   'Goldoni',
#   '1707-1793',
#   None,
#   None,
#   'Le bourru bienfaisant, comédie en trois actes et en prose'),
#  ('c:stcv:12866920',
#   2,
#   'Ribadière, de la',
#   'de la Ribardiere',
#   '',
#   None,
#   None,
#   'Les aveux indiscrets, opera comique'),
#  ('c:stcv:12866939',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Le maître en droit, opera-comique en deux actes'),
#  ('c:stcv:12867300',
#   2,
#   'Moens, Adrianus',
#   'Adrianus Moens',
#   '',
#   None,
#   None,
#   'Enchiridion religiosorvm'),
#  ('c:stcv:12867792',
#   2,
#   'Woestwinckel, Petrus',
#   'Woestwinckel, Petrus',
#   '1595-1673',
#   None,
#   None,
#   'Mariæ virginis [...] excellentia, potentia, misericordia; compendio exposita'),
#  ('c:stcv:12867804',
#   2,
#   'Moens, Adrianus',
#   'Adr. Moens',
#   '',
#   None,
#   None,
#   'Privilegia a variis pontificibvs concessa ac demvm a Clemente VIII. confirmata pro fratribvs III. ord. S. Francisci de poenit. qvi svnt de capitvlo Zepperensi'),
#  ('c:stcv:12867845',
#   2,
#   'Drexelius, Hieremias',
#   'Hieremias Drexelius',
#   '1581-1638',
#   None,
#   None,
#   'Aloe amari sed salubris succi ieivnivm'),
#  ('c:stcv:12867878',
#   2,
#   'F.C.A.M.R.',
#   'F.C.A.M.R.',
#   '',
#   None,
#   None,
#   'Clarissimo viro D. Francisco Lams I.V.L. urbis Antuerpien. electo syndico'),
#  ('c:stcv:12867885',
#   2,
#   'Bardonville',
#   'Bardonville',
#   '',
#   None,
#   None,
#   'Le Confiteor dv chancelier av temps de Pasqves'),
#  ('c:stcv:12867907',
#   2,
#   'More, Henry',
#   'Henricvs Morvs',
#   '1586-1661',
#   None,
#   None,
#   'Vita et doctrina Christi domini'),
#  ('c:stcv:12867929',
#   2,
#   'Kempis, a, Joannes Wilhelmus',
#   'Ioannes VVilhelmus a Kempis',
#   '',
#   None,
#   None,
#   'Praxis medica de præservatione & curatione morbi articularis & calculi'),
#  ('c:stcv:12867974',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   "La desiree paix entra sa majesté catholicque d'-Espagne, & les seigneurs estats des provinces unies d'Hollande, &c. Faite & signée à Munster le huictiesme de ianvier 1647"),
#  ('c:stcv:12868566',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Epinicia sanctis martyribvs victoribvs trivmphatoribvs, quorum sacra corpora [...] in thronis [...] templi domus professæ societatis Iesu Antuerpiæ fuêre reposita'),
#  ('c:stcv:12868625',
#   2,
#   'Rivius, Joannes',
#   'Ioannes Rivius',
#   '1599-1665',
#   None,
#   None,
#   'S. Thomas a Villanova [...] a S.D.N. Alexandro papa VII. in divorvm nvmervm relatvs anno M.DC.LVIII.'),
#  ('c:stcv:12868640',
#   2,
#   'Henschenius, Godefridus',
#   'Godefridus Henschenius',
#   '1601-1681',
#   None,
#   None,
#   'De episcopatv Traiectensi [...] diatriba'),
#  ('c:stcv:12868663',
#   2,
#   'Alexander VII [Pope]',
#   'Philomathus',
#   '1599-1667',
#   None,
#   None,
#   'Mvsæ ivveniles'),
#  ('c:stcv:12868736',
#   2,
#   'Alvarez, Manuel',
#   'Emmanvel Alvarus',
#   '1526-1583',
#   None,
#   None,
#   'Grammatica sive Institvtionvm lingvæ Latinæ liber secvndvs'),
#  ('c:stcv:12868749',
#   2,
#   'Alvarez, Manuel',
#   'Emmanvel Alvarus',
#   '1526-1583',
#   None,
#   None,
#   'Syntaxis sive Institvtionvm lingvæ Latinæ liber tertivs. In usum studiosorum societatis Iesv'),
#  ('c:stcv:12868755',
#   2,
#   'Alvarez, Manuel',
#   'Emmanvel Alvarus',
#   '1526-1583',
#   None,
#   None,
#   'Prosodia sive Institvtionvm lingvæ Latinæ liber qvartvs. In usum studiosorum societatis Iesv'),
#  ('c:stcv:12868758',
#   2,
#   'Soarez, Cyprianus',
#   'Cyprianus Soarez',
#   '1524-1593',
#   None,
#   None,
#   'De arte rhetorica libri tres'),
#  ('c:stcv:12868994',
#   2,
#   'Torsellini, Horatius',
#   'Horatius Tvrsellinus',
#   '1544-1599',
#   None,
#   None,
#   'De particvlis Latinæ orationis'),
#  ('c:stcv:12869036',
#   2,
#   'Fernandez, Marcos',
#   'Marcos Fernandez',
#   '',
#   None,
#   None,
#   'Olla podrida a la Española, compuesta i façonada en la description de Munster en Vesfalia con salsa Sarracena i Africana'),
#  ('c:stcv:12869148',
#   2,
#   'Urban VIII [Pope]',
#   'Urbanus papa VIII',
#   '1568-1644',
#   None,
#   None,
#   'Bulla [...] pro clero & religiosis missionariis ad propagandam fidem. In fœderatis Belgij provinciis'),
#  ('c:stcv:12869229',
#   2,
#   'Cicero, Marcus Tullius',
#   'M. Tvllius Cicero',
#   '106 ante Chr.-43 ante Chr.',
#   None,
#   None,
#   'Ad Qvintvm fratrem de oratore dialogi tres'),
#  ('c:stcv:12869264',
#   2,
#   'Stanihurstus, Guilielmus',
#   'Guilielmus Stanihurstus',
#   '1601-1663',
#   None,
#   None,
#   'Dei immortalis in corpore mortali patientis historia'),
#  ('c:stcv:12869479',
#   2,
#   'Favart, Charles-Simon',
#   'Favat [!]',
#   '1710-1792',
#   None,
#   None,
#   "l'Anglois a Bordeaux; comedie en un acte et en vers libres"),
#  ('c:stcv:12869497',
#   2,
#   'Favart, Charles-Simon',
#   'Favart, Charles-Simon',
#   '1710-1792',
#   None,
#   None,
#   'La fausse duègne ou Le jaloux corrigé par force, opera-comique en deux actes'),
#  ('c:stcv:12869500',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   "Il étoit tems ou l'Ecuyer temeraire, petit opera-comique en un acte"),
#  ('c:stcv:12869588',
#   2,
#   'Sedaine, Michel Jean',
#   'Sedaine, Michel Jean',
#   '1719-1797',
#   None,
#   None,
#   'Rose et Colas, comédie en un acte'),
#  ('c:stcv:12869609',
#   2,
#   'Romagnesi, Jean-Antoine',
#   'Romagnesi',
#   '1690-1742',
#   None,
#   None,
#   'Samson'),
#  ('c:stcv:12869812',
#   2,
#   'Puteanus, Erycius',
#   'E. Pvteanus',
#   '1574-1646',
#   None,
#   None,
#   'De indvciis avt pace Belgarvm dissertationes variæ'),
#  ('c:stcv:12869845',
#   2,
#   'Tamburino, Thomas',
#   'Thomas Tambvrinus',
#   '',
#   None,
#   None,
#   'De sacrificio missæ expedite celebrando libri tres'),
#  ('c:stcv:12869872',
#   2,
#   'P.N.S.N.',
#   'P.N.S.N.',
#   '',
#   None,
#   None,
#   'Disceptatio et justa defensio septem controversiarum [...] super collatione verbo scriptoque habitâ inter duos patres Embricenses è societate Iesu, & duos ministros reformatæ religionis. Adversus D. Petrum Cabeljavium, ministrum Leidensem'),
#  ('c:stcv:12869899',
#   2,
#   'Cambry, de, P.',
#   'P. de Cambry',
#   '',
#   None,
#   None,
#   "Abbregé de la vie de dame Ienne de Cambry, premierement religieuse de l'ordre de S. Augustin à Tournay, & depuis sœur Ienne Marie de la Presentation recluse lez Lille"),
#  ('c:stcv:12869970',
#   2,
#   'Urban VIII [Pope]',
#   'Vrbanus [...] papa VIII',
#   '1568-1644',
#   None,
#   None,
#   'Confirmatio constitutionum Pij papæ V. & Gregorij XIII. prohibentium quasdam theologorum sententias, & opiniones. Nec non prohibitio libri, cui titulus, Augustinus, Cornelij Iansenij [...] excusi Lovanij, typis Iacobi Zegeri, anno 1640.'),
#  ('c:stcv:12869997',
#   2,
#   'Chifflet, Laurent',
#   'Lavrent Chiflet',
#   '1598-1658',
#   None,
#   None,
#   "Essay d'vne parfaite grammaire de la langve françoise"),
#  ('c:stcv:12870045',
#   2,
#   'Cicero, Marcus Tullius',
#   'M. T. Cicero',
#   '106 ante Chr.-43 ante Chr.',
#   None,
#   None,
#   'Celebriores sententiæ, apophthegmata et similitvdines ex operibus M.T. Ciceronis collectæ'),
#  ('c:stcv:12870054',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Catechisme ov Doctrine chrestienne divisée en cinq parties, et quarante & vne leçons'),
#  ('c:stcv:12870121',
#   2,
#   'Drexelius, Hieremias',
#   'Hieremias Drexelius',
#   '1581-1638',
#   None,
#   None,
#   'Rhetorica cælestis seu Attente precandi scientia')]

# %%
stcv_dict = {}
for row in data:
    key, value = row[0], row[-1]
    stcv_dict[key] = value

# %%
stcv_dict
# Out:
# {'c:stcv:12854444': 'Apologie des ministres du culte, qui ont prêté la déclaration exigée par la loi du 7 vendém. an 4. contre les critiques de mm. Dédoyar & Vanhoren, les Motifs de Malines & autres brochures',
#  'c:stcv:12854501': 'Observations sur la déclaration exigée des ministres des cultes, en vertu de la loi du 7 vendémiaire, an 4',
#  'c:stcv:12854549': "l'Eloquence chrétienne dans l'idée et dans la pratique",
#  'c:stcv:12854587': 'Verscheyde leeringen en exempelen der oude vaders',
#  'c:stcv:12854599': 'Godtvruchtige leeringen en gebeden voor de eerste communie',
#  'c:stcv:12857052': "Le prince immortel tiré sur la vie & la fin glorieuse de son altesse royale don Ferdinand d'Avstriche",
#  'c:stcv:12857069': 'Trivmphvs rosarii a sede apostolica decretvs sodalitati B. virginis Mariæ',
#  'c:stcv:12857131': 'In statvas antiqvitatis et elegantias Arvndellianas cento Maronianvs',
#  'c:stcv:12857158': 'Inde[x] librorvm qvi in typographia Plantiniana excvsi venales nvnc exstant',
#  'c:stcv:12857275': 'Theologiæ practicæ in qua de actibus humanis [...] agitur [...] pars quarta',
#  'c:stcv:12857374': 'Gedenk-stuk op de geregtigheden der Brabanders, en de beledigingen, die tegen de zelve geschied zyn uyt den naem van S.M. den keyzer en koning, sedert eenige jaeren',
#  'c:stcv:12857912': 'David regivs psaltes descriptvs',
#  'c:stcv:12857923': 'Librito de la cofradia de la s.ta Crvz de Hoboqve de la dioceis de Anberes',
#  'c:stcv:12858124': 'Het vereerlykt Oostenryk, in den oorlog tegen den koning van Pruyssen',
#  'c:stcv:12858392': 'Tobias morali doctrinâ illustratus [...] ex posthumis libellis quartus. Monachii M.DC.XLI.',
#  'c:stcv:12858408': 'Aloe amari sed salubris succi ieivnivm',
#  'c:stcv:12858413': 'Rosæ selectissimarum virtutum, quas Dei mater orbi exhibet, pars II.',
#  'c:stcv:12858468': 'Orationvm volvmen II.',
#  'c:stcv:12858494': "Nouvvelle chronicqve contenant les choses plus memorables advenues en ces Pays-bas, depuis l'an 1500. jusques à l'an present",
#  'c:stcv:12858622': 'Enchiridion piarvm meditationvm in omnes dominicas',
#  'c:stcv:12858690': 'Pvrgatorivm catholicè assertum',
#  'c:stcv:12858729': "Svccessi principali della monarchia di Spagna nell'anno M.DC.XXXIX.",
#  'c:stcv:12858795': 'Solis et artis adulteria',
#  'c:stcv:12859250': 'Heerlycke ende gheluckighe reyse na het Heyligh Landt ende de stadt van Jerusalem [...]. Het eerste deel',
#  'c:stcv:12859427': 'Conciones funebres et nuptiales',
#  'c:stcv:12859712': 'Novus candidatus rhetoricæ',
#  'c:stcv:12859754': 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta',
#  'c:stcv:12859820': 'Corona gothica, castellana, y avstriaca',
#  'c:stcv:12859871': 'La vie et le martyre de Louis XVI [...] immolé le 21 janvier 1793; avec un examen du décret régicide',
#  'c:stcv:12859905': "Traité touchant la suppression de la mendicité et l'administration des pauvres dans la ville d'Anvers",
#  'c:stcv:12859931': 'Recueil de loix concernant le régime hypothécaire a les déclarations foncieres',
#  'c:stcv:12860028': 'Analogia Veteris ac Novi Testamenti',
#  'c:stcv:12860136': 'Appèl a la raison des écrits et libelles publiés par la passion, contre les jésuites de France',
#  'c:stcv:12860498': 'Copy van een seecker boecxken dat onlanckx is vvt ghegaen, trackterende van een miraeckel oft spectakel, dat te Amsterdam geschiet is',
#  'c:stcv:12860697': 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta',
#  'c:stcv:12860711': 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta',
#  'c:stcv:12860736': 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta',
#  'c:stcv:12861541': 'Fastorvm libri VI. Tristivm libri V. De ponto libri IV. In Ibin ad Liviam',
#  'c:stcv:12861606': 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta',
#  'c:stcv:12861734': 'De officiis libri tres. Cato major, vel de senectute. Lælius, vel de amicitia. Paradoxa stoicorum sex. Somnium Scipionis',
#  'c:stcv:12861760': 'De officiis libri tres. Cato major, vel de senectute. Lælius, vel de amicitia. Paradoxa stoicorum sex. Somnium Scipionis',
#  'c:stcv:12861798': 'Flores, ex operibus illius singulari judicio selecti',
#  'c:stcv:12861813': 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta',
#  'c:stcv:12862032': 'Les provinciaux détrompés. Comédie en trois actes',
#  'c:stcv:12862035': "l'Heureuse pêche, comédie pour les ombres a scenes changeantes",
#  'c:stcv:12862038': "l'Ecole des bourgeois, comédie en trois actes",
#  'c:stcv:12862053': 'La rosiere de Salenci, comédie en trois actes',
#  'c:stcv:12862058': 'Le bal masqué, opéra-comique en un acte',
#  'c:stcv:12862118': 'Les deux amis, ou Le négociant de Lyon, drame en cinq actes en prose',
#  'c:stcv:12862125': 'Le persifleur, comédie en trois actes et en vers',
#  'c:stcv:12862153': 'La mere jalouse, comédie en trois actes et en vers',
#  'c:stcv:12862168': 'Le cri de la nature, comédie en vers et en un acte',
#  'c:stcv:12863004': 'Commentarii in totam primam partem S. Thom. Aqvinatis',
#  'c:stcv:12865436': 'Opera omnia, sex tomis comprehensa',
#  'c:stcv:12865677': 'Ars rhetorica',
#  'c:stcv:12865828': 'Breviarium theologicum continens definitiones, descriptiones, & explicationes terminorum theologicorum',
#  'c:stcv:12866841': 'Les chérusques, tragédie',
#  'c:stcv:12866854': 'Pygmalion, scene lyrique',
#  'c:stcv:12866862': "l'Orphelin anglais, drame, en trois actes, en prose",
#  'c:stcv:12866867': 'Bélisaire, drame en cinq actes et en vers',
#  'c:stcv:12866905': "l'Amant déguisé ou Le jardinier supposé, comédie en un acte",
#  'c:stcv:12866912': 'Le bourru bienfaisant, comédie en trois actes et en prose',
#  'c:stcv:12866920': 'Les aveux indiscrets, opera comique',
#  'c:stcv:12866939': 'Le maître en droit, opera-comique en deux actes',
#  'c:stcv:12867300': 'Enchiridion religiosorvm',
#  'c:stcv:12867792': 'Mariæ virginis [...] excellentia, potentia, misericordia; compendio exposita',
#  'c:stcv:12867804': 'Privilegia a variis pontificibvs concessa ac demvm a Clemente VIII. confirmata pro fratribvs III. ord. S. Francisci de poenit. qvi svnt de capitvlo Zepperensi',
#  'c:stcv:12867845': 'Aloe amari sed salubris succi ieivnivm',
#  'c:stcv:12867878': 'Clarissimo viro D. Francisco Lams I.V.L. urbis Antuerpien. electo syndico',
#  'c:stcv:12867885': 'Le Confiteor dv chancelier av temps de Pasqves',
#  'c:stcv:12867907': 'Vita et doctrina Christi domini',
#  'c:stcv:12867929': 'Praxis medica de præservatione & curatione morbi articularis & calculi',
#  'c:stcv:12867974': "La desiree paix entra sa majesté catholicque d'-Espagne, & les seigneurs estats des provinces unies d'Hollande, &c. Faite & signée à Munster le huictiesme de ianvier 1647",
#  'c:stcv:12868566': 'Epinicia sanctis martyribvs victoribvs trivmphatoribvs, quorum sacra corpora [...] in thronis [...] templi domus professæ societatis Iesu Antuerpiæ fuêre reposita',
#  'c:stcv:12868625': 'S. Thomas a Villanova [...] a S.D.N. Alexandro papa VII. in divorvm nvmervm relatvs anno M.DC.LVIII.',
#  'c:stcv:12868640': 'De episcopatv Traiectensi [...] diatriba',
#  'c:stcv:12868663': 'Mvsæ ivveniles',
#  'c:stcv:12868736': 'Grammatica sive Institvtionvm lingvæ Latinæ liber secvndvs',
#  'c:stcv:12868749': 'Syntaxis sive Institvtionvm lingvæ Latinæ liber tertivs. In usum studiosorum societatis Iesv',
#  'c:stcv:12868755': 'Prosodia sive Institvtionvm lingvæ Latinæ liber qvartvs. In usum studiosorum societatis Iesv',
#  'c:stcv:12868758': 'De arte rhetorica libri tres',
#  'c:stcv:12868994': 'De particvlis Latinæ orationis',
#  'c:stcv:12869036': 'Olla podrida a la Española, compuesta i façonada en la description de Munster en Vesfalia con salsa Sarracena i Africana',
#  'c:stcv:12869148': 'Bulla [...] pro clero & religiosis missionariis ad propagandam fidem. In fœderatis Belgij provinciis',
#  'c:stcv:12869229': 'Ad Qvintvm fratrem de oratore dialogi tres',
#  'c:stcv:12869264': 'Dei immortalis in corpore mortali patientis historia',
#  'c:stcv:12869479': "l'Anglois a Bordeaux; comedie en un acte et en vers libres",
#  'c:stcv:12869497': 'La fausse duègne ou Le jaloux corrigé par force, opera-comique en deux actes',
#  'c:stcv:12869500': "Il étoit tems ou l'Ecuyer temeraire, petit opera-comique en un acte",
#  'c:stcv:12869588': 'Rose et Colas, comédie en un acte',
#  'c:stcv:12869609': 'Samson',
#  'c:stcv:12869812': 'De indvciis avt pace Belgarvm dissertationes variæ',
#  'c:stcv:12869845': 'De sacrificio missæ expedite celebrando libri tres',
#  'c:stcv:12869872': 'Disceptatio et justa defensio septem controversiarum [...] super collatione verbo scriptoque habitâ inter duos patres Embricenses è societate Iesu, & duos ministros reformatæ religionis. Adversus D. Petrum Cabeljavium, ministrum Leidensem',
#  'c:stcv:12869899': "Abbregé de la vie de dame Ienne de Cambry, premierement religieuse de l'ordre de S. Augustin à Tournay, & depuis sœur Ienne Marie de la Presentation recluse lez Lille",
#  'c:stcv:12869970': 'Confirmatio constitutionum Pij papæ V. & Gregorij XIII. prohibentium quasdam theologorum sententias, & opiniones. Nec non prohibitio libri, cui titulus, Augustinus, Cornelij Iansenij [...] excusi Lovanij, typis Iacobi Zegeri, anno 1640.',
#  'c:stcv:12869997': "Essay d'vne parfaite grammaire de la langve françoise",
#  'c:stcv:12870045': 'Celebriores sententiæ, apophthegmata et similitvdines ex operibus M.T. Ciceronis collectæ',
#  'c:stcv:12870054': 'Catechisme ov Doctrine chrestienne divisée en cinq parties, et quarante & vne leçons',
#  'c:stcv:12870121': 'Rhetorica cælestis seu Attente precandi scientia'}

# %%
conn.close()

# %%
import urllib.parse
import urllib.request
import urllib.error
from urllib.parse import quote

import json
import sys
from urllib.request import urlopen
from urllib.error import HTTPError, URLError
import lxml
import lxml.etree
import xml.etree.ElementTree as ET
from xml.etree.ElementTree import fromstring, ElementTree

# %%
# from xml.etree import ElementTree

# %%
HBP = "https://sru.gbv.de/hpb?version=2.0&operation=searchRetrieve&query="

# %%
def clean(string: str) -> str:
    """
    clean input string and URL encode
    """
    string = string.strip()
    string = string.casefold()
    string = urllib.parse.quote(string)
    return string


def query_hbp(dict):
    hbp_lists = []
    for value in stcv_dict.values():
        temp_list = []
        url = HBP + clean(value) + '&startRecord=1&maximumRecords=10&recordSchema=marcxml'
        try:
            with urllib.request.urlopen(url) as query:
                f = query.read()
                tree = lxml.etree.fromstring(f, parser=None)
                root = tree.getroottree()
                for element in tree.iter('{http://www.loc.gov/MARC21/slim}datafield'):
                    for item in element.items():
                        if item == ('tag', '035'):
                            for child in element:
                                for item in child.items():
                                    if item == ('code', 'a'):
                                        temp_list.append(child.text)
                hbp_lists.append(temp_list)
        except urllib.error.HTTPError as HTTPerr:
            exit(HTTPerr.code)
            print('Something went wrong')
        except urllib.error.URLError as URLerr:
            exit(URLerr)
            print('Something went wrong')
    return(hbp_lists)
    print(len(hbp_lists))
    
query_hbp(stcv_dict)
# Out:
# [[],
#  ['BE-AnVE.c:stcv:12913022',
#   'BE-AnVE.c:stcv:12854501',
#   'DE-604.VK.BV021245268',
#   'BE-KBR00.CAT.1_1397836',
#   'FR-751131015.CG.FRBNF363412130000000',
#   'FR-751131015.CG.FRBNF303526230000006'],
#  ['(OCoLC)253314165',
#   'DE-601.GVK.454683766',
#   '(OCoLC)168782481 ',
#   'BE-AnVE.c:stcv:12854549',
#   'BE-KBR00.CAT.1_1732080',
#   'BE-KBR00.CAT.1_1604695',
#   'BE-KBR00.CAT.1_1506014',
#   'DE-603.351439676',
#   'FR-341725201.SUDOC.099981661',
#   '(OCoLC)244521759 ',
#   'SpMaUC.BH.b22061861',
#   'FR-341725201.SUDOC.135439248',
#   '(OCoLC)257480982',
#   'DE-601.GVK.153387947',
#   '(OCoLC)169122583 '],
#  ['BE-AnVE.c:stcv:12854587', 'NL-0100030000.STCN.328229482'],
#  ['BE-AnVE.c:stcv:12854599',
#   'BE-AnVE.c:stcv:3207115',
#   'NL-0100030000.STCN.328577863',
#   'BE-AnVE.c:stcv:6170080',
#   'BE-AnVE.c:stcv:3207179',
#   'BE-AnVE.c:stcv:3139737',
#   'NL-0100030000.STCN.317873369',
#   'NL-0100030000.STCN.316078743',
#   'NL-0100030000.STCN.314809163'],
#  ['BE-AnVE.c:stcv:12857052'],
#  [],
#  ['BE-AnVE.c:stcv:12857131'],
#  ['(OCoLC)48731412',
#   'DE-601.GVK.135430852',
#   '(OCoLC)169517145 ',
#   'BE-AnVE.c:stcv:12923714',
#   'BE-AnVE.c:stcv:12857158'],
#  [],
#  [],
#  ['BE-AnVE.c:stcv:12902263',
#   'DE-603.436428180',
#   'DE-604.VK.BV011522337',
#   'NL-0100030000.EPE.851589219',
#   'Cty.01.1313445',
#   '(OCoLC)168320120',
#   'NL-0100030000.STCN.292227574',
#   '(OCoLC)258334259',
#   'DE-601.GVK.223303194',
#   '(OCoLC)169750793 ',
#   'BE-AnVE.c:stcv:12857912',
#   'DE-604.VK.BV012115176',
#   'Cty.01.9116935'],
#  [],
#  ['BE-AnVE.c:stcv:12858124', 'NL-0100030000.STCN.328583650'],
#  [],
#  ['BE-AnVE.c:stcv:12867845',
#   'CZ-PrNK.STT.stt20100013276',
#   'DE-604.VK.BV011522322',
#   'NL-0100030000.EPE.081553374',
#   'Cty.01.1313442',
#   '(OCoLC)168320112',
#   'GB-UkOxU.01.015213171',
#   '(OCoLC)166989565',
#   '(OCoLC)258210922',
#   'DE-601.GVK.151080631',
#   '(OCoLC)167965765 ',
#   'GB-UkOxU.01.013348262',
#   '(OCoLC)166942492',
#   'BE-AnVE.c:stcv:12858408',
#   'CZ-PrNK.STT.stt20150151815'],
#  [],
#  [],
#  [],
#  ['BE-AnVE.c:stcv:12858622',
#   'CZ-PrNK.STT.stt20150131495',
#   'CZ-PrNK.STT.stt20150130615',
#   'DE-604.VK.BV017215911',
#   '(OCoLC)169500055 ',
#   'HU-SzSEK.01.bibJAT00008577',
#   'DE-604.VK.BV017215786',
#   'DE-604.VK.BV042632979',
#   '(OCoLC)254319025',
#   'DE-601.GVK.557340144',
#   'DE-604.VK.BV017216010',
#   'UK-LAMBETHANA.01.139205'],
#  ['BE-AnVE.c:stcv:12858690', 'DE-604.VK.BV001355495', '(OCoLC)814513848 '],
#  [],
#  ['BE-AnVE.c:stcv:12858795',
#   'IT-ICCU.NAPE033028',
#   'NL-UtRU.01.002008665',
#   'GB-UkOxU.01.016077328',
#   'PL-BJ.01.vtls000622244',
#   'FR-341725201.SUDOC.135381134',
#   'DE-604.VK.BV001385454',
#   '(OCoLC)814546581 ',
#   '(OCoLC)56862237',
#   'DE-601.GVK.162244495',
#   '(OCoLC)169179324 '],
#  [],
#  ['IT-ICCU.CFIE044723',
#   'IT-ICCU.CFIE044646',
#   'CZ-PrNK.STT.stt20140123510',
#   'DE-604.VK.BV040922922',
#   'DE-604.VK.BV037438143',
#   'GB-UkOxU.01.015260321',
#   '(OCoLC)167000585',
#   '(OCoLC)169354329 ',
#   'SI-50001.RK.065646',
#   '(OCoLC)168729750 ',
#   'SpMaBN.01.BNE20030770004',
#   'IT-ICCU.PBEE008270',
#   'DE-604.VK.BV037437941'],
#  ['FR-341725201.SUDOC.140484825',
#   'NL-0100030000.STCN.317645897',
#   'IT-ICCU.BVEE111611',
#   'FR-341725201.SUDOC.155653903',
#   'CZ-PrNK.STT.stt20150143885',
#   'DE-604.VK.BV022440360',
#   'FR-341725201.SUDOC.140480382',
#   'DE-604.VK.BV010865984',
#   'CZ-PrNK.STT.stt20120070401',
#   'CZ-PrNK.STT.stt20110025874'],
#  [],
#  ['CZ-PrNK.STT.stt20110043096',
#   'DE-601.GVK.621039624',
#   '(OCoLC)833485591',
#   'DE-601.GVK.270437851',
#   '(OCoLC)169540625 ',
#   'CZ-PrNK.STT.stt20120058882',
#   'CZ-PrNK.STT.stt20120058878',
#   'CZ-PrNK.STT.stt20030000449',
#   '(OCoLC)837556984',
#   'DE-601.GVK.62103732X',
#   'DE-601.GVK.621032107',
#   '(OCoLC)833485584',
#   'DE-601.GVK.270437711',
#   '(OCoLC)169540620 ',
#   '(OCoLC)833485547',
#   'DE-601.GVK.270437568',
#   '(OCoLC)169540616 '],
#  [],
#  ['BE-AnVE.c:stcv:12859905',
#   'BE-KBR00.CAT.1_1188679',
#   'FR-751131015.CG.FRBNF393115480000007',
#   'FR-751131015.CG.FRBNF336293500000001',
#   'DE-604.VK.BV008019052',
#   '(OCoLC)815349613 '],
#  ['BE-AnVE.c:stcv:12859931', 'BE-KBR00.CAT.1_1327344'],
#  ['NL-UtRU.01.000671780',
#   'BE-AnVE.c:stcv:12915131',
#   'NL-0100030000.EPE.067443818',
#   'NL-UtRU.01.001245517',
#   'FR-751131015.CG.FRBNF300748130000009',
#   '(OCoLC)168029529 ',
#   'SpMaBN.01.BNE20029037616',
#   '(OCoLC)168029695 ',
#   'SpMaBN.01.BNE20029037638',
#   '(OCoLC)168029602 ',
#   'SpMaBN.01.BNE20029037627',
#   'IT-ICCU.TO0E038478',
#   'BE-AnVE.c:stcv:12923431'],
#  ['BE-AnVE.c:stcv:12860136'],
#  ['BE-AnVE.c:stcv:12860498'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['BE-AnVE.c:stcv:12861798', 'DE-604.VK.BV012720877', 'DE-604.VK.BV010776196'],
#  [],
#  [],
#  ['BE-AnVE.c:stcv:12862035',
#   'NL-0100030000.EPE.256303932',
#   'FR-751131015.CG.FRBNF397656210000006',
#   'FR-751131015.CG.FRBNF393246410000009',
#   'FR-751131015.CG.FRBNF334162860000006'],
#  ['(OCoLC)168203848 ',
#   'SpMaBN.01.BNE20040944883',
#   'GB-UkOxU.01.012283205',
#   'FR-341725201.SUDOC.086844822',
#   'FR-751131015.CG.FRBNF387545660000002',
#   'FR-751131015.CG.FRBNF386531260000008',
#   '(OCoLC)844240064',
#   'DE-601.GVK.147041686',
#   '(OCoLC)169490711 ',
#   'IT-ICCU.RMLE008885',
#   'Cty.01.1862497',
#   '(OCoLC)753034219',
#   'GB-UkOxU.01.013699371',
#   'FR-341725201.SUDOC.099605198'],
#  ['BE-KBR00.CAT.1_1493039',
#   'IT-ICCU.LIGE004529',
#   'IT-ICCU.MUS0035980',
#   'NL-0100030000.EPE.255871953',
#   '(OCoLC)837538289',
#   'DE-601.GVK.62095910X',
#   'GB-UkOxU.01.012849396',
#   '(OCoLC)166933809',
#   'GB-UkOxU.01.012849394',
#   '(OCoLC)166933808',
#   'IT-ICCU.CFIE051168',
#   'DE-604.VK.BV042372842',
#   'BE-AnVE.c:stcv:12862053'],
#  ['BE-AnVE.c:stcv:12862058',
#   'BE-KBR00.CAT.1_195550',
#   'BE-KBR00.CAT.1_195554',
#   'FR-751131015.CG.FRBNF308914260000000'],
#  ['PlWaU.01.xx002770867',
#   'US-icn.01.225593',
#   '(OCoLC)169875408 ',
#   'RuSpRNB.A2V16.50623',
#   'IT-ICCU.NAPE048785',
#   '(OCoLC)254187774',
#   'DE-601.GVK.556810368',
#   'FR-341725201.SUDOC.099656175',
#   'Cty.01.1967487',
#   '(OCoLC)168914034',
#   'FR-693836101.CG.0001755065',
#   '(OCoLC)246314205',
#   'DE-601.GVK.254283276',
#   '(OCoLC)169205719 ',
#   'FR-751131015.CG.FRBNF386571830000002'],
#  ['BE-AnVE.c:stcv:12862125',
#   'GB-StGlU.01.b16879260',
#   'IT-ICCU.TO0E095395',
#   'IT-ICCU.RMLE009354',
#   'DE-604.VK.BV035258746',
#   'DE-604.VK.BV010676799',
#   'US-mdbj.01.1081993',
#   '(OCoLC)255473721',
#   'DE-601.GVK.509276911',
#   'BE-KBR00.CAT.1_1364710'],
#  ['(OCoLC)252273134',
#   'DE-601.GVK.443359989',
#   'US-icn.01.224888',
#   'DE-603.052410021',
#   'BE-AnVE.c:stcv:12862153',
#   'IT-ICCU.UTOE674646',
#   'IT-ICCU.TO0E086381',
#   'IT-ICCU.LO1E012628',
#   'IT-ICCU.LO1E012626',
#   'CZ-PrNK.STT.stt20150142155',
#   'DE-604.VK.BV003548519'],
#  ['FR-751131015.CG.FRBNF315692890000009',
#   'FR-751131015.CG.FRBNF316248360000003',
#   'BE-AnVE.c:stcv:12862168',
#   'IT-ICCU.TO0E095419',
#   'DE-604.VK.BV035257809',
#   'FR-341725201.SUDOC.162015100',
#   'BE-KBR00.CAT.1_1363510',
#   'BE-KBR00.CAT.1_1658906',
#   'BE-KBR00.CAT.1_1195154',
#   'FR-751131015.CG.FRBNF306264470000002'],
#  [],
#  ['IT-ICCU.UM1E005908',
#   'IT-ICCU.UBOE007273',
#   'DE-604.VK.BV013878998',
#   'DE-604.VK.BV011407157',
#   'DE-604.VK.BV011407118',
#   'DE-604.VK.BV011407182',
#   'GB-StGlU.01.b22103697',
#   'DE-603.109916212',
#   'DE-603.10991614X',
#   'DE-603.109915941'],
#  ['(OCoLC)168091753 ',
#   'SpMaBN.01.BNE20030485805',
#   'IT-ICCU.LO1E010863',
#   'DE-601.GVK.304731293',
#   'GB-UkOxU.01.015527989',
#   'FR-341725201.SUDOC.096436514',
#   'FR-751131015.CG.FRBNF353843470000000',
#   'DE-604.VK.BV001508410',
#   '(OCoLC)814660779 ',
#   '(OCoLC)257621704',
#   'DE-601.GVK.142849235',
#   '(OCoLC)168049101 ',
#   'NL-UtRU.01.001288349',
#   'DE-604.VK.BV001700302',
#   '(OCoLC)814875316 '],
#  ['BE-AnVE.c:stcv:7009616',
#   'BE-AnVE.c:stcv:7009597',
#   'NL-UtRU.01.001345648',
#   'CZ-PrNK.STT.stt20140111967',
#   'DE-604.VK.BV042261561',
#   'IT-ICCU.BVEE059423',
#   'DE-604.VK.BV040931222',
#   'DE-604.VK.BV008524631',
#   '(OCoLC)257664185',
#   'DE-601.GVK.194507173',
#   'FR-341725201.SUDOC.065127854'],
#  ['IT-ICCU.UBOE032443',
#   'BE-AnVE.c:stcv:12866841',
#   'IT-ICCU.UTOE674537',
#   'DE-604.VK.BV010235692',
#   'US-mdbj.01.1084260',
#   '(OCoLC)253210539',
#   'DE-601.GVK.456675019',
#   'GB-UkOxU.01.012290878',
#   '(OCoLC)167279837',
#   'FR-341725201.SUDOC.116309326',
#   'FR-341725201.SUDOC.11420974X',
#   'BE-KBR00.CAT.1_1393325'],
#  ['FR-751131015.CG.FRBNF325889210000005',
#   'FR-751131015.CG.FRBNF386557440000008',
#   '(OCoLC)696376996 ',
#   'NL-0100030000.PB.853321183',
#   '(OCoLC)696380480 ',
#   'NL-0100030000.PB.860330664',
#   'FR-751131015.CG.FRBNF386557430000000',
#   'GB-UkOxU.01.013791710',
#   'FR-751131015.CG.FRBNF387692310000007',
#   'FR-751131015.CG.FRBNF335388340000001',
#   '(OCoLC)249189463',
#   'DE-601.GVK.37618003X',
#   '(OCoLC)168719581 ',
#   'BE-KBR00.CAT.1_437539'],
#  ['FR-341725201.SUDOC.100155820',
#   'FR-751131015.CG.FRBNF386549660000001',
#   'US-mdbj.01.1023233',
#   'Cty.01.2475965',
#   '(OCoLC)168969659',
#   'BE-AnVE.c:stcv:12866862',
#   'US-icn.01.590011',
#   'NL-0100030000.EPE.241190762',
#   'NL-UtRU.01.000324827',
#   'FR-341725201.SUDOC.152291059',
#   'FR-751131015.CG.FRBNF386549640000007'],
#  ['FR-751131015.CG.FRBNF386553610000007',
#   'FR-341725201.SUDOC.116823755',
#   'FR-751131015.CG.FRBNF38655360000000X',
#   'BE-AnVE.c:stcv:12866867',
#   'BE-KBR00.CAT.1_1366000',
#   'BE-KBR00.CAT.1_1366807',
#   'BE-KBR00.CAT.1_1366403',
#   'BE-KBR00.CAT.1_1365998',
#   'BE-KBR00.CAT.1_1314891',
#   'BE-KBR00.CAT.1_1195141'],
#  ['IT-ICCU.MUS0038800',
#   'GB-UkOxU.01.012755639',
#   '(OCoLC)166932806',
#   'FR-751131015.CG.FRBNF386542690000005',
#   '(OCoLC)168023700 ',
#   'DK-810010.KBD.x481942717',
#   'BE-AnVE.c:stcv:12866905',
#   'US-icn.01.724762',
#   'Cty.01.4208939',
#   '(OCoLC)169689766',
#   'FR-341725201.SUDOC.150779208',
#   'FR-341725201.SUDOC.099933470',
#   'BE-KBR00.CAT.1_464646'],
#  ['(OCoLC)839004569',
#   'DE-601.GVK.685403378',
#   'GB-UkOxU.01.012939544',
#   'US-mdbj.01.1464242',
#   'DE-601.GVK.720247640',
#   'FR-751131015.CG.FRBNF38693357000000X',
#   'US-mdbj.01.1023244',
#   'Cty.01.2289919',
#   '(OCoLC)168951628',
#   '(OCoLC)16309023',
#   'DE-601.GVK.153543639',
#   'FR-751131015.CG.FRBNF386933560000002',
#   '(OCoLC)168743120 ',
#   'SpMaBN.01.BNE20030770453'],
#  ['BE-KBR00.CAT.1_194739',
#   'FR-751131015.CG.FRBNF386560350000005',
#   '(OCoLC)168023700 ',
#   'DK-810010.KBD.x481942717',
#   'Cty.01.2241379',
#   '(OCoLC)168947980',
#   'Cty.01.2209075',
#   '(OCoLC)168946507',
#   'Cty.01.1887184',
#   '(OCoLC)168892362',
#   'IT-ICCU.NAPE004770',
#   'Cty.01.2745158',
#   '(OCoLC)753051946',
#   'Cty.01.2242213',
#   '(OCoLC)168948106',
#   'GB-UkOxU.01.012750328'],
#  ['(OCoLC)168023700 ',
#   'DK-810010.KBD.x481942717',
#   'BE-KBR00.CAT.1_410157',
#   'FR-751131015.CG.FRBNF386566830000005',
#   'FR-751131015.CG.FRBNF386548920000006',
#   'IT-ICCU.MUS0036976',
#   '(OCoLC)255876299',
#   'DE-601.GVK.526251042',
#   'BE-KBR00.CAT.1_472747',
#   'BE-KBR00.CAT.1_410154',
#   'BE-KBR00.CAT.1_410153',
#   'BE-KBR00.CAT.1_397582'],
#  ['BE-AnVE.c:stcv:12867300', 'DE-604.VK.BV014330428'],
#  [],
#  [],
#  ['BE-AnVE.c:stcv:12867845',
#   'CZ-PrNK.STT.stt20100013276',
#   'DE-604.VK.BV011522322',
#   'NL-0100030000.EPE.081553374',
#   'Cty.01.1313442',
#   '(OCoLC)168320112',
#   'GB-UkOxU.01.015213171',
#   '(OCoLC)166989565',
#   '(OCoLC)258210922',
#   'DE-601.GVK.151080631',
#   '(OCoLC)167965765 ',
#   'GB-UkOxU.01.013348262',
#   '(OCoLC)166942492',
#   'BE-AnVE.c:stcv:12858408',
#   'CZ-PrNK.STT.stt20150151815'],
#  [],
#  ['BE-AnVE.c:stcv:12867885', 'DE-604.VK.BV026170088'],
#  ['CZ-PrNK.STT.stt20140112456',
#   'CH-000003-X.006415090',
#   'DE-604.VK.BV010438703',
#   'GB-StGlU.01.b16537725',
#   'FR-693836101.CG.0001437978',
#   'DE-604.VK.BV001445001',
#   '(OCoLC)814596327 ',
#   '(OCoLC)168172009 ',
#   'SpMaBN.01.BNE20040477930',
#   'DE-604.VK.BV011574120',
#   'DE-604.VK.BV011574113',
#   'DE-604.VK.BV011574098'],
#  ['BE-AnVE.c:stcv:12867929',
#   'FR-341725201.SUDOC.100067409',
#   'FR-341725201.SUDOC.044361696'],
#  [],
#  [],
#  [],
#  [],
#  ['CZ-PrNK.STT.stt20150137822',
#   'DE-604.VK.BV009000204',
#   'NL-0100030000.STCN.21511454X',
#   '(OCoLC)168818207 ',
#   '(OCoLC)45984859',
#   'DE-601.GVK.143955578',
#   '(OCoLC)169253502 ',
#   'BE-AnVE.c:stcv:12868663',
#   'CZ-PrNK.STT.stt20150137440',
#   'Cty.01.1226457',
#   '(OCoLC)168159633',
#   '(OCoLC)836513473',
#   'DE-601.GVK.530197766',
#   'GB-StEdNL.01.2238935',
#   '(OCoLC)168479658 ',
#   'NL-0100030000.EPE.143219650'],
#  ['BE-AnVE.c:stcv:12868736', 'GB-UkOxU.01.015759885'],
#  [],
#  [],
#  ['IT-ICCU.VIAE020579',
#   'PL-BJ.01.vtls000707519',
#   'IT-ICCU.PUVE024144',
#   'IT-ICCU.TO0E124684',
#   'PL-BJ.01.vtls000854081',
#   'DE-604.VK.BV010801592',
#   'DE-604.VK.BV001691694',
#   '(OCoLC)814831835 ',
#   'IT-ICCU.VIAE031547',
#   'CZ-PrNK.STT.stt20140107793',
#   'DE-604.VK.BV022326076'],
#  ['GB-StGlU.01.b17392044',
#   'CZ-PrNK.STT.stt20140100406',
#   'DE-604.VK.BV026539167',
#   '(OCoLC)174825296',
#   'DE-601.GVK.242915655',
#   '(OCoLC)169605010 ',
#   'GB-StGlU.01.b17330385',
#   'DE-603.426094689',
#   'DE-601.GVK.738372641',
#   '(OCoLC)169112841 ',
#   'DE-601.GVK.244152616',
#   'DE-604.VK.BV041814244',
#   'DE-604.VK.BV025266574'],
#  ['BE-AnVE.c:stcv:12869036'],
#  [],
#  ['FR-341725201.SUDOC.123906024',
#   '(OCoLC)257497767',
#   'DE-601.GVK.143890352',
#   '(OCoLC)169249363 ',
#   'CZ-PrNK.STT.stt20110046029',
#   'DE-604.VK.BV019883353',
#   'BE-AnVE.c:stcv:12869229',
#   '(OCoLC)257884212',
#   'DE-601.GVK.141573104',
#   '(OCoLC)168576025 ',
#   'DE-603.432815252',
#   'Cty.01.1313315',
#   '(OCoLC)168319748'],
#  ['DE-604.VK.BV040988239',
#   'DE-603.181635763',
#   'CZ-PrNK.STT.stt20150137285',
#   'DE-604.VK.BV013637978',
#   '(OCoLC)169498508 ',
#   'HU-SzSEK.01.bibJAT00007699',
#   '(OCoLC)169347788 ',
#   'SI-50001.RK.014592',
#   'DE-604.VK.BV010806139',
#   'DE-604.VK.BV007325702',
#   'DE-603.18163435X',
#   'DE-604.VK.BV013889952'],
#  ['US-icn.01.365209',
#   'FR-341725201.SUDOC.103450688',
#   'FR-751131015.CG.FRBNF304222880000000',
#   'FR-341725201.SUDOC.131731521',
#   'FR-751131015.CG.FRBNF304222870000003',
#   'FR-751131015.CG.FRBNF399653750000006',
#   'FR-341725201.SUDOC.09993356X',
#   'FR-751131015.CG.FRBNF304222860000006',
#   '(OCoLC)254135889',
#   'DE-601.GVK.479095760',
#   '(OCoLC)168493390 ',
#   'IT-ICCU.RMLE008758'],
#  ['BE-AnVE.c:stcv:12869497'],
#  ['BE-AnVE.c:stcv:12869500', 'BE-KBR00.CAT.1_400338', 'BE-KBR00.CAT.1_400335'],
#  ['DE-604.VK.BV023239434',
#   'BE-KBR00.CAT.1_1780441',
#   'FR-751131015.CG.FRBNF399705600000005',
#   'BE-KBR00.CAT.1_444076',
#   'FR-751131015.CG.FRBNF386559320000008',
#   'IT-ICCU.MUS0024678',
#   'FR-341725201.SUDOC.054448743',
#   'DE-604.VK.BV019741153',
#   'BE-KBR00.CAT.1_444072',
#   'IT-ICCU.MUS0024676'],
#  ['(OCoLC)169879124 ',
#   'RuSpRNB.A2V16.53867',
#   'DE-603.426459814',
#   'DE-603.362975531',
#   'DE-603.362975507',
#   'DE-603.362975442',
#   'DE-603.362975388',
#   'DE-603.362975353',
#   'DE-603.362975248',
#   'DE-603.362975205',
#   'DE-603.362975183'],
#  ['BE-AnVE.c:stcv:12869812',
#   'DE-601.GVK.489072526',
#   'FR-341725201.SUDOC.128414472',
#   'NL-0100030000.STCN.115875689',
#   '(OCoLC)168304256 ',
#   '(OCoLC)81782261',
#   'DE-601.GVK.151373531',
#   '(OCoLC)169414431 '],
#  ['(OCoLC)254291581',
#   'DE-601.GVK.479587760',
#   '(OCoLC)168493901 ',
#   'DE-604.VK.BV001693099',
#   '(OCoLC)814842547 ',
#   'BE-AnVE.c:stcv:12869845',
#   'NL-0100030000.EPE.153578017',
#   'DE-604.VK.BV001693097',
#   '(OCoLC)814842544 ',
#   '(OCoLC)253019462',
#   'DE-601.GVK.456325859',
#   '(OCoLC)168474437 ',
#   'IT-ICCU.VIAE026243',
#   'DE-604.VK.BV042333949',
#   'IT-ICCU.BVEE046409'],
#  [],
#  [],
#  [],
#  ['BE-AnVE.c:stcv:3197053',
#   'BE-AnVE.c:stcv:12916698',
#   'NL-0100030000.STCN.315997222',
#   'BE-AnVE.c:stcv:3126455',
#   'BE-AnVE.c:stcv:12879644',
#   'NL-0100030000.STCN.314349677',
#   'GB-UkOxU.01.013767871',
#   '(OCoLC)166958547',
#   'BE-AnVE.c:stcv:3166791',
#   'BE-AnVE.c:stcv:12869997',
#   'CZ-PrNK.STT.stt20140100407'],
#  [],
#  ['BE-AnVE.c:stcv:12870054'],
#  ['DE-604.VK.BV010204729',
#   'BE-AnVE.c:stcv:12870121',
#   'IT-ICCU.UM1E003734',
#   'DE-604.VK.BV013334115',
#   'NL-UtRU.01.001311278',
#   'Cty.01.1315987',
#   '(OCoLC)168327786',
#   'NL-0100030000.STCN.292019882',
#   'GB-UkOxU.01.015100738',
#   '(OCoLC)166970207',
#   'BE-KBR00.CAT.1_1486308',
#   'BE-KBR00.CAT.1_1483999']]

# %%
hbp_lists = query_hbp(stcv_dict)
len(hbp_lists)
# Out:
# 100

# %%
def zip_stcv_hbp(list1, list2):
    list1 = list(stcv_dict.keys())
    list2 = hbp_lists
    matches = dict(zip(list1, list2))
    return matches

# %%
stcv_list = list(stcv_dict.keys())

# %%
matching_ids = zip_stcv_hbp(stcv_list, hbp_lists)

# %%
matching_ids
# Out:
# {'c:stcv:12854444': [],
#  'c:stcv:12854501': ['BE-AnVE.c:stcv:12913022',
#   'BE-AnVE.c:stcv:12854501',
#   'DE-604.VK.BV021245268',
#   'BE-KBR00.CAT.1_1397836',
#   'FR-751131015.CG.FRBNF363412130000000',
#   'FR-751131015.CG.FRBNF303526230000006'],
#  'c:stcv:12854549': ['(OCoLC)253314165',
#   'DE-601.GVK.454683766',
#   '(OCoLC)168782481 ',
#   'BE-AnVE.c:stcv:12854549',
#   'BE-KBR00.CAT.1_1732080',
#   'BE-KBR00.CAT.1_1604695',
#   'BE-KBR00.CAT.1_1506014',
#   'DE-603.351439676',
#   'FR-341725201.SUDOC.099981661',
#   '(OCoLC)244521759 ',
#   'SpMaUC.BH.b22061861',
#   'FR-341725201.SUDOC.135439248',
#   '(OCoLC)257480982',
#   'DE-601.GVK.153387947',
#   '(OCoLC)169122583 '],
#  'c:stcv:12854587': ['BE-AnVE.c:stcv:12854587',
#   'NL-0100030000.STCN.328229482'],
#  'c:stcv:12854599': ['BE-AnVE.c:stcv:12854599',
#   'BE-AnVE.c:stcv:3207115',
#   'NL-0100030000.STCN.328577863',
#   'BE-AnVE.c:stcv:6170080',
#   'BE-AnVE.c:stcv:3207179',
#   'BE-AnVE.c:stcv:3139737',
#   'NL-0100030000.STCN.317873369',
#   'NL-0100030000.STCN.316078743',
#   'NL-0100030000.STCN.314809163'],
#  'c:stcv:12857052': ['BE-AnVE.c:stcv:12857052'],
#  'c:stcv:12857069': [],
#  'c:stcv:12857131': ['BE-AnVE.c:stcv:12857131'],
#  'c:stcv:12857158': ['(OCoLC)48731412',
#   'DE-601.GVK.135430852',
#   '(OCoLC)169517145 ',
#   'BE-AnVE.c:stcv:12923714',
#   'BE-AnVE.c:stcv:12857158'],
#  'c:stcv:12857275': [],
#  'c:stcv:12857374': [],
#  'c:stcv:12857912': ['BE-AnVE.c:stcv:12902263',
#   'DE-603.436428180',
#   'DE-604.VK.BV011522337',
#   'NL-0100030000.EPE.851589219',
#   'Cty.01.1313445',
#   '(OCoLC)168320120',
#   'NL-0100030000.STCN.292227574',
#   '(OCoLC)258334259',
#   'DE-601.GVK.223303194',
#   '(OCoLC)169750793 ',
#   'BE-AnVE.c:stcv:12857912',
#   'DE-604.VK.BV012115176',
#   'Cty.01.9116935'],
#  'c:stcv:12857923': [],
#  'c:stcv:12858124': ['BE-AnVE.c:stcv:12858124',
#   'NL-0100030000.STCN.328583650'],
#  'c:stcv:12858392': [],
#  'c:stcv:12858408': ['BE-AnVE.c:stcv:12867845',
#   'CZ-PrNK.STT.stt20100013276',
#   'DE-604.VK.BV011522322',
#   'NL-0100030000.EPE.081553374',
#   'Cty.01.1313442',
#   '(OCoLC)168320112',
#   'GB-UkOxU.01.015213171',
#   '(OCoLC)166989565',
#   '(OCoLC)258210922',
#   'DE-601.GVK.151080631',
#   '(OCoLC)167965765 ',
#   'GB-UkOxU.01.013348262',
#   '(OCoLC)166942492',
#   'BE-AnVE.c:stcv:12858408',
#   'CZ-PrNK.STT.stt20150151815'],
#  'c:stcv:12858413': [],
#  'c:stcv:12858468': [],
#  'c:stcv:12858494': [],
#  'c:stcv:12858622': ['BE-AnVE.c:stcv:12858622',
#   'CZ-PrNK.STT.stt20150131495',
#   'CZ-PrNK.STT.stt20150130615',
#   'DE-604.VK.BV017215911',
#   '(OCoLC)169500055 ',
#   'HU-SzSEK.01.bibJAT00008577',
#   'DE-604.VK.BV017215786',
#   'DE-604.VK.BV042632979',
#   '(OCoLC)254319025',
#   'DE-601.GVK.557340144',
#   'DE-604.VK.BV017216010',
#   'UK-LAMBETHANA.01.139205'],
#  'c:stcv:12858690': ['BE-AnVE.c:stcv:12858690',
#   'DE-604.VK.BV001355495',
#   '(OCoLC)814513848 '],
#  'c:stcv:12858729': [],
#  'c:stcv:12858795': ['BE-AnVE.c:stcv:12858795',
#   'IT-ICCU.NAPE033028',
#   'NL-UtRU.01.002008665',
#   'GB-UkOxU.01.016077328',
#   'PL-BJ.01.vtls000622244',
#   'FR-341725201.SUDOC.135381134',
#   'DE-604.VK.BV001385454',
#   '(OCoLC)814546581 ',
#   '(OCoLC)56862237',
#   'DE-601.GVK.162244495',
#   '(OCoLC)169179324 '],
#  'c:stcv:12859250': [],
#  'c:stcv:12859427': ['IT-ICCU.CFIE044723',
#   'IT-ICCU.CFIE044646',
#   'CZ-PrNK.STT.stt20140123510',
#   'DE-604.VK.BV040922922',
#   'DE-604.VK.BV037438143',
#   'GB-UkOxU.01.015260321',
#   '(OCoLC)167000585',
#   '(OCoLC)169354329 ',
#   'SI-50001.RK.065646',
#   '(OCoLC)168729750 ',
#   'SpMaBN.01.BNE20030770004',
#   'IT-ICCU.PBEE008270',
#   'DE-604.VK.BV037437941'],
#  'c:stcv:12859712': ['FR-341725201.SUDOC.140484825',
#   'NL-0100030000.STCN.317645897',
#   'IT-ICCU.BVEE111611',
#   'FR-341725201.SUDOC.155653903',
#   'CZ-PrNK.STT.stt20150143885',
#   'DE-604.VK.BV022440360',
#   'FR-341725201.SUDOC.140480382',
#   'DE-604.VK.BV010865984',
#   'CZ-PrNK.STT.stt20120070401',
#   'CZ-PrNK.STT.stt20110025874'],
#  'c:stcv:12859754': [],
#  'c:stcv:12859820': ['CZ-PrNK.STT.stt20110043096',
#   'DE-601.GVK.621039624',
#   '(OCoLC)833485591',
#   'DE-601.GVK.270437851',
#   '(OCoLC)169540625 ',
#   'CZ-PrNK.STT.stt20120058882',
#   'CZ-PrNK.STT.stt20120058878',
#   'CZ-PrNK.STT.stt20030000449',
#   '(OCoLC)837556984',
#   'DE-601.GVK.62103732X',
#   'DE-601.GVK.621032107',
#   '(OCoLC)833485584',
#   'DE-601.GVK.270437711',
#   '(OCoLC)169540620 ',
#   '(OCoLC)833485547',
#   'DE-601.GVK.270437568',
#   '(OCoLC)169540616 '],
#  'c:stcv:12859871': [],
#  'c:stcv:12859905': ['BE-AnVE.c:stcv:12859905',
#   'BE-KBR00.CAT.1_1188679',
#   'FR-751131015.CG.FRBNF393115480000007',
#   'FR-751131015.CG.FRBNF336293500000001',
#   'DE-604.VK.BV008019052',
#   '(OCoLC)815349613 '],
#  'c:stcv:12859931': ['BE-AnVE.c:stcv:12859931', 'BE-KBR00.CAT.1_1327344'],
#  'c:stcv:12860028': ['NL-UtRU.01.000671780',
#   'BE-AnVE.c:stcv:12915131',
#   'NL-0100030000.EPE.067443818',
#   'NL-UtRU.01.001245517',
#   'FR-751131015.CG.FRBNF300748130000009',
#   '(OCoLC)168029529 ',
#   'SpMaBN.01.BNE20029037616',
#   '(OCoLC)168029695 ',
#   'SpMaBN.01.BNE20029037638',
#   '(OCoLC)168029602 ',
#   'SpMaBN.01.BNE20029037627',
#   'IT-ICCU.TO0E038478',
#   'BE-AnVE.c:stcv:12923431'],
#  'c:stcv:12860136': ['BE-AnVE.c:stcv:12860136'],
#  'c:stcv:12860498': ['BE-AnVE.c:stcv:12860498'],
#  'c:stcv:12860697': [],
#  'c:stcv:12860711': [],
#  'c:stcv:12860736': [],
#  'c:stcv:12861541': [],
#  'c:stcv:12861606': [],
#  'c:stcv:12861734': [],
#  'c:stcv:12861760': [],
#  'c:stcv:12861798': ['BE-AnVE.c:stcv:12861798',
#   'DE-604.VK.BV012720877',
#   'DE-604.VK.BV010776196'],
#  'c:stcv:12861813': [],
#  'c:stcv:12862032': [],
#  'c:stcv:12862035': ['BE-AnVE.c:stcv:12862035',
#   'NL-0100030000.EPE.256303932',
#   'FR-751131015.CG.FRBNF397656210000006',
#   'FR-751131015.CG.FRBNF393246410000009',
#   'FR-751131015.CG.FRBNF334162860000006'],
#  'c:stcv:12862038': ['(OCoLC)168203848 ',
#   'SpMaBN.01.BNE20040944883',
#   'GB-UkOxU.01.012283205',
#   'FR-341725201.SUDOC.086844822',
#   'FR-751131015.CG.FRBNF387545660000002',
#   'FR-751131015.CG.FRBNF386531260000008',
#   '(OCoLC)844240064',
#   'DE-601.GVK.147041686',
#   '(OCoLC)169490711 ',
#   'IT-ICCU.RMLE008885',
#   'Cty.01.1862497',
#   '(OCoLC)753034219',
#   'GB-UkOxU.01.013699371',
#   'FR-341725201.SUDOC.099605198'],
#  'c:stcv:12862053': ['BE-KBR00.CAT.1_1493039',
#   'IT-ICCU.LIGE004529',
#   'IT-ICCU.MUS0035980',
#   'NL-0100030000.EPE.255871953',
#   '(OCoLC)837538289',
#   'DE-601.GVK.62095910X',
#   'GB-UkOxU.01.012849396',
#   '(OCoLC)166933809',
#   'GB-UkOxU.01.012849394',
#   '(OCoLC)166933808',
#   'IT-ICCU.CFIE051168',
#   'DE-604.VK.BV042372842',
#   'BE-AnVE.c:stcv:12862053'],
#  'c:stcv:12862058': ['BE-AnVE.c:stcv:12862058',
#   'BE-KBR00.CAT.1_195550',
#   'BE-KBR00.CAT.1_195554',
#   'FR-751131015.CG.FRBNF308914260000000'],
#  'c:stcv:12862118': ['PlWaU.01.xx002770867',
#   'US-icn.01.225593',
#   '(OCoLC)169875408 ',
#   'RuSpRNB.A2V16.50623',
#   'IT-ICCU.NAPE048785',
#   '(OCoLC)254187774',
#   'DE-601.GVK.556810368',
#   'FR-341725201.SUDOC.099656175',
#   'Cty.01.1967487',
#   '(OCoLC)168914034',
#   'FR-693836101.CG.0001755065',
#   '(OCoLC)246314205',
#   'DE-601.GVK.254283276',
#   '(OCoLC)169205719 ',
#   'FR-751131015.CG.FRBNF386571830000002'],
#  'c:stcv:12862125': ['BE-AnVE.c:stcv:12862125',
#   'GB-StGlU.01.b16879260',
#   'IT-ICCU.TO0E095395',
#   'IT-ICCU.RMLE009354',
#   'DE-604.VK.BV035258746',
#   'DE-604.VK.BV010676799',
#   'US-mdbj.01.1081993',
#   '(OCoLC)255473721',
#   'DE-601.GVK.509276911',
#   'BE-KBR00.CAT.1_1364710'],
#  'c:stcv:12862153': ['(OCoLC)252273134',
#   'DE-601.GVK.443359989',
#   'US-icn.01.224888',
#   'DE-603.052410021',
#   'BE-AnVE.c:stcv:12862153',
#   'IT-ICCU.UTOE674646',
#   'IT-ICCU.TO0E086381',
#   'IT-ICCU.LO1E012628',
#   'IT-ICCU.LO1E012626',
#   'CZ-PrNK.STT.stt20150142155',
#   'DE-604.VK.BV003548519'],
#  'c:stcv:12862168': ['FR-751131015.CG.FRBNF315692890000009',
#   'FR-751131015.CG.FRBNF316248360000003',
#   'BE-AnVE.c:stcv:12862168',
#   'IT-ICCU.TO0E095419',
#   'DE-604.VK.BV035257809',
#   'FR-341725201.SUDOC.162015100',
#   'BE-KBR00.CAT.1_1363510',
#   'BE-KBR00.CAT.1_1658906',
#   'BE-KBR00.CAT.1_1195154',
#   'FR-751131015.CG.FRBNF306264470000002'],
#  'c:stcv:12863004': [],
#  'c:stcv:12865436': ['IT-ICCU.UM1E005908',
#   'IT-ICCU.UBOE007273',
#   'DE-604.VK.BV013878998',
#   'DE-604.VK.BV011407157',
#   'DE-604.VK.BV011407118',
#   'DE-604.VK.BV011407182',
#   'GB-StGlU.01.b22103697',
#   'DE-603.109916212',
#   'DE-603.10991614X',
#   'DE-603.109915941'],
#  'c:stcv:12865677': ['(OCoLC)168091753 ',
#   'SpMaBN.01.BNE20030485805',
#   'IT-ICCU.LO1E010863',
#   'DE-601.GVK.304731293',
#   'GB-UkOxU.01.015527989',
#   'FR-341725201.SUDOC.096436514',
#   'FR-751131015.CG.FRBNF353843470000000',
#   'DE-604.VK.BV001508410',
#   '(OCoLC)814660779 ',
#   '(OCoLC)257621704',
#   'DE-601.GVK.142849235',
#   '(OCoLC)168049101 ',
#   'NL-UtRU.01.001288349',
#   'DE-604.VK.BV001700302',
#   '(OCoLC)814875316 '],
#  'c:stcv:12865828': ['BE-AnVE.c:stcv:7009616',
#   'BE-AnVE.c:stcv:7009597',
#   'NL-UtRU.01.001345648',
#   'CZ-PrNK.STT.stt20140111967',
#   'DE-604.VK.BV042261561',
#   'IT-ICCU.BVEE059423',
#   'DE-604.VK.BV040931222',
#   'DE-604.VK.BV008524631',
#   '(OCoLC)257664185',
#   'DE-601.GVK.194507173',
#   'FR-341725201.SUDOC.065127854'],
#  'c:stcv:12866841': ['IT-ICCU.UBOE032443',
#   'BE-AnVE.c:stcv:12866841',
#   'IT-ICCU.UTOE674537',
#   'DE-604.VK.BV010235692',
#   'US-mdbj.01.1084260',
#   '(OCoLC)253210539',
#   'DE-601.GVK.456675019',
#   'GB-UkOxU.01.012290878',
#   '(OCoLC)167279837',
#   'FR-341725201.SUDOC.116309326',
#   'FR-341725201.SUDOC.11420974X',
#   'BE-KBR00.CAT.1_1393325'],
#  'c:stcv:12866854': ['FR-751131015.CG.FRBNF325889210000005',
#   'FR-751131015.CG.FRBNF386557440000008',
#   '(OCoLC)696376996 ',
#   'NL-0100030000.PB.853321183',
#   '(OCoLC)696380480 ',
#   'NL-0100030000.PB.860330664',
#   'FR-751131015.CG.FRBNF386557430000000',
#   'GB-UkOxU.01.013791710',
#   'FR-751131015.CG.FRBNF387692310000007',
#   'FR-751131015.CG.FRBNF335388340000001',
#   '(OCoLC)249189463',
#   'DE-601.GVK.37618003X',
#   '(OCoLC)168719581 ',
#   'BE-KBR00.CAT.1_437539'],
#  'c:stcv:12866862': ['FR-341725201.SUDOC.100155820',
#   'FR-751131015.CG.FRBNF386549660000001',
#   'US-mdbj.01.1023233',
#   'Cty.01.2475965',
#   '(OCoLC)168969659',
#   'BE-AnVE.c:stcv:12866862',
#   'US-icn.01.590011',
#   'NL-0100030000.EPE.241190762',
#   'NL-UtRU.01.000324827',
#   'FR-341725201.SUDOC.152291059',
#   'FR-751131015.CG.FRBNF386549640000007'],
#  'c:stcv:12866867': ['FR-751131015.CG.FRBNF386553610000007',
#   'FR-341725201.SUDOC.116823755',
#   'FR-751131015.CG.FRBNF38655360000000X',
#   'BE-AnVE.c:stcv:12866867',
#   'BE-KBR00.CAT.1_1366000',
#   'BE-KBR00.CAT.1_1366807',
#   'BE-KBR00.CAT.1_1366403',
#   'BE-KBR00.CAT.1_1365998',
#   'BE-KBR00.CAT.1_1314891',
#   'BE-KBR00.CAT.1_1195141'],
#  'c:stcv:12866905': ['IT-ICCU.MUS0038800',
#   'GB-UkOxU.01.012755639',
#   '(OCoLC)166932806',
#   'FR-751131015.CG.FRBNF386542690000005',
#   '(OCoLC)168023700 ',
#   'DK-810010.KBD.x481942717',
#   'BE-AnVE.c:stcv:12866905',
#   'US-icn.01.724762',
#   'Cty.01.4208939',
#   '(OCoLC)169689766',
#   'FR-341725201.SUDOC.150779208',
#   'FR-341725201.SUDOC.099933470',
#   'BE-KBR00.CAT.1_464646'],
#  'c:stcv:12866912': ['(OCoLC)839004569',
#   'DE-601.GVK.685403378',
#   'GB-UkOxU.01.012939544',
#   'US-mdbj.01.1464242',
#   'DE-601.GVK.720247640',
#   'FR-751131015.CG.FRBNF38693357000000X',
#   'US-mdbj.01.1023244',
#   'Cty.01.2289919',
#   '(OCoLC)168951628',
#   '(OCoLC)16309023',
#   'DE-601.GVK.153543639',
#   'FR-751131015.CG.FRBNF386933560000002',
#   '(OCoLC)168743120 ',
#   'SpMaBN.01.BNE20030770453'],
#  'c:stcv:12866920': ['BE-KBR00.CAT.1_194739',
#   'FR-751131015.CG.FRBNF386560350000005',
#   '(OCoLC)168023700 ',
#   'DK-810010.KBD.x481942717',
#   'Cty.01.2241379',
#   '(OCoLC)168947980',
#   'Cty.01.2209075',
#   '(OCoLC)168946507',
#   'Cty.01.1887184',
#   '(OCoLC)168892362',
#   'IT-ICCU.NAPE004770',
#   'Cty.01.2745158',
#   '(OCoLC)753051946',
#   'Cty.01.2242213',
#   '(OCoLC)168948106',
#   'GB-UkOxU.01.012750328'],
#  'c:stcv:12866939': ['(OCoLC)168023700 ',
#   'DK-810010.KBD.x481942717',
#   'BE-KBR00.CAT.1_410157',
#   'FR-751131015.CG.FRBNF386566830000005',
#   'FR-751131015.CG.FRBNF386548920000006',
#   'IT-ICCU.MUS0036976',
#   '(OCoLC)255876299',
#   'DE-601.GVK.526251042',
#   'BE-KBR00.CAT.1_472747',
#   'BE-KBR00.CAT.1_410154',
#   'BE-KBR00.CAT.1_410153',
#   'BE-KBR00.CAT.1_397582'],
#  'c:stcv:12867300': ['BE-AnVE.c:stcv:12867300', 'DE-604.VK.BV014330428'],
#  'c:stcv:12867792': [],
#  'c:stcv:12867804': [],
#  'c:stcv:12867845': ['BE-AnVE.c:stcv:12867845',
#   'CZ-PrNK.STT.stt20100013276',
#   'DE-604.VK.BV011522322',
#   'NL-0100030000.EPE.081553374',
#   'Cty.01.1313442',
#   '(OCoLC)168320112',
#   'GB-UkOxU.01.015213171',
#   '(OCoLC)166989565',
#   '(OCoLC)258210922',
#   'DE-601.GVK.151080631',
#   '(OCoLC)167965765 ',
#   'GB-UkOxU.01.013348262',
#   '(OCoLC)166942492',
#   'BE-AnVE.c:stcv:12858408',
#   'CZ-PrNK.STT.stt20150151815'],
#  'c:stcv:12867878': [],
#  'c:stcv:12867885': ['BE-AnVE.c:stcv:12867885', 'DE-604.VK.BV026170088'],
#  'c:stcv:12867907': ['CZ-PrNK.STT.stt20140112456',
#   'CH-000003-X.006415090',
#   'DE-604.VK.BV010438703',
#   'GB-StGlU.01.b16537725',
#   'FR-693836101.CG.0001437978',
#   'DE-604.VK.BV001445001',
#   '(OCoLC)814596327 ',
#   '(OCoLC)168172009 ',
#   'SpMaBN.01.BNE20040477930',
#   'DE-604.VK.BV011574120',
#   'DE-604.VK.BV011574113',
#   'DE-604.VK.BV011574098'],
#  'c:stcv:12867929': ['BE-AnVE.c:stcv:12867929',
#   'FR-341725201.SUDOC.100067409',
#   'FR-341725201.SUDOC.044361696'],
#  'c:stcv:12867974': [],
#  'c:stcv:12868566': [],
#  'c:stcv:12868625': [],
#  'c:stcv:12868640': [],
#  'c:stcv:12868663': ['CZ-PrNK.STT.stt20150137822',
#   'DE-604.VK.BV009000204',
#   'NL-0100030000.STCN.21511454X',
#   '(OCoLC)168818207 ',
#   '(OCoLC)45984859',
#   'DE-601.GVK.143955578',
#   '(OCoLC)169253502 ',
#   'BE-AnVE.c:stcv:12868663',
#   'CZ-PrNK.STT.stt20150137440',
#   'Cty.01.1226457',
#   '(OCoLC)168159633',
#   '(OCoLC)836513473',
#   'DE-601.GVK.530197766',
#   'GB-StEdNL.01.2238935',
#   '(OCoLC)168479658 ',
#   'NL-0100030000.EPE.143219650'],
#  'c:stcv:12868736': ['BE-AnVE.c:stcv:12868736', 'GB-UkOxU.01.015759885'],
#  'c:stcv:12868749': [],
#  'c:stcv:12868755': [],
#  'c:stcv:12868758': ['IT-ICCU.VIAE020579',
#   'PL-BJ.01.vtls000707519',
#   'IT-ICCU.PUVE024144',
#   'IT-ICCU.TO0E124684',
#   'PL-BJ.01.vtls000854081',
#   'DE-604.VK.BV010801592',
#   'DE-604.VK.BV001691694',
#   '(OCoLC)814831835 ',
#   'IT-ICCU.VIAE031547',
#   'CZ-PrNK.STT.stt20140107793',
#   'DE-604.VK.BV022326076'],
#  'c:stcv:12868994': ['GB-StGlU.01.b17392044',
#   'CZ-PrNK.STT.stt20140100406',
#   'DE-604.VK.BV026539167',
#   '(OCoLC)174825296',
#   'DE-601.GVK.242915655',
#   '(OCoLC)169605010 ',
#   'GB-StGlU.01.b17330385',
#   'DE-603.426094689',
#   'DE-601.GVK.738372641',
#   '(OCoLC)169112841 ',
#   'DE-601.GVK.244152616',
#   'DE-604.VK.BV041814244',
#   'DE-604.VK.BV025266574'],
#  'c:stcv:12869036': ['BE-AnVE.c:stcv:12869036'],
#  'c:stcv:12869148': [],
#  'c:stcv:12869229': ['FR-341725201.SUDOC.123906024',
#   '(OCoLC)257497767',
#   'DE-601.GVK.143890352',
#   '(OCoLC)169249363 ',
#   'CZ-PrNK.STT.stt20110046029',
#   'DE-604.VK.BV019883353',
#   'BE-AnVE.c:stcv:12869229',
#   '(OCoLC)257884212',
#   'DE-601.GVK.141573104',
#   '(OCoLC)168576025 ',
#   'DE-603.432815252',
#   'Cty.01.1313315',
#   '(OCoLC)168319748'],
#  'c:stcv:12869264': ['DE-604.VK.BV040988239',
#   'DE-603.181635763',
#   'CZ-PrNK.STT.stt20150137285',
#   'DE-604.VK.BV013637978',
#   '(OCoLC)169498508 ',
#   'HU-SzSEK.01.bibJAT00007699',
#   '(OCoLC)169347788 ',
#   'SI-50001.RK.014592',
#   'DE-604.VK.BV010806139',
#   'DE-604.VK.BV007325702',
#   'DE-603.18163435X',
#   'DE-604.VK.BV013889952'],
#  'c:stcv:12869479': ['US-icn.01.365209',
#   'FR-341725201.SUDOC.103450688',
#   'FR-751131015.CG.FRBNF304222880000000',
#   'FR-341725201.SUDOC.131731521',
#   'FR-751131015.CG.FRBNF304222870000003',
#   'FR-751131015.CG.FRBNF399653750000006',
#   'FR-341725201.SUDOC.09993356X',
#   'FR-751131015.CG.FRBNF304222860000006',
#   '(OCoLC)254135889',
#   'DE-601.GVK.479095760',
#   '(OCoLC)168493390 ',
#   'IT-ICCU.RMLE008758'],
#  'c:stcv:12869497': ['BE-AnVE.c:stcv:12869497'],
#  'c:stcv:12869500': ['BE-AnVE.c:stcv:12869500',
#   'BE-KBR00.CAT.1_400338',
#   'BE-KBR00.CAT.1_400335'],
#  'c:stcv:12869588': ['DE-604.VK.BV023239434',
#   'BE-KBR00.CAT.1_1780441',
#   'FR-751131015.CG.FRBNF399705600000005',
#   'BE-KBR00.CAT.1_444076',
#   'FR-751131015.CG.FRBNF386559320000008',
#   'IT-ICCU.MUS0024678',
#   'FR-341725201.SUDOC.054448743',
#   'DE-604.VK.BV019741153',
#   'BE-KBR00.CAT.1_444072',
#   'IT-ICCU.MUS0024676'],
#  'c:stcv:12869609': ['(OCoLC)169879124 ',
#   'RuSpRNB.A2V16.53867',
#   'DE-603.426459814',
#   'DE-603.362975531',
#   'DE-603.362975507',
#   'DE-603.362975442',
#   'DE-603.362975388',
#   'DE-603.362975353',
#   'DE-603.362975248',
#   'DE-603.362975205',
#   'DE-603.362975183'],
#  'c:stcv:12869812': ['BE-AnVE.c:stcv:12869812',
#   'DE-601.GVK.489072526',
#   'FR-341725201.SUDOC.128414472',
#   'NL-0100030000.STCN.115875689',
#   '(OCoLC)168304256 ',
#   '(OCoLC)81782261',
#   'DE-601.GVK.151373531',
#   '(OCoLC)169414431 '],
#  'c:stcv:12869845': ['(OCoLC)254291581',
#   'DE-601.GVK.479587760',
#   '(OCoLC)168493901 ',
#   'DE-604.VK.BV001693099',
#   '(OCoLC)814842547 ',
#   'BE-AnVE.c:stcv:12869845',
#   'NL-0100030000.EPE.153578017',
#   'DE-604.VK.BV001693097',
#   '(OCoLC)814842544 ',
#   '(OCoLC)253019462',
#   'DE-601.GVK.456325859',
#   '(OCoLC)168474437 ',
#   'IT-ICCU.VIAE026243',
#   'DE-604.VK.BV042333949',
#   'IT-ICCU.BVEE046409'],
#  'c:stcv:12869872': [],
#  'c:stcv:12869899': [],
#  'c:stcv:12869970': [],
#  'c:stcv:12869997': ['BE-AnVE.c:stcv:3197053',
#   'BE-AnVE.c:stcv:12916698',
#   'NL-0100030000.STCN.315997222',
#   'BE-AnVE.c:stcv:3126455',
#   'BE-AnVE.c:stcv:12879644',
#   'NL-0100030000.STCN.314349677',
#   'GB-UkOxU.01.013767871',
#   '(OCoLC)166958547',
#   'BE-AnVE.c:stcv:3166791',
#   'BE-AnVE.c:stcv:12869997',
#   'CZ-PrNK.STT.stt20140100407'],
#  'c:stcv:12870045': [],
#  'c:stcv:12870054': ['BE-AnVE.c:stcv:12870054'],
#  'c:stcv:12870121': ['DE-604.VK.BV010204729',
#   'BE-AnVE.c:stcv:12870121',
#   'IT-ICCU.UM1E003734',
#   'DE-604.VK.BV013334115',
#   'NL-UtRU.01.001311278',
#   'Cty.01.1315987',
#   '(OCoLC)168327786',
#   'NL-0100030000.STCN.292019882',
#   'GB-UkOxU.01.015100738',
#   '(OCoLC)166970207',
#   'BE-KBR00.CAT.1_1486308',
#   'BE-KBR00.CAT.1_1483999']}
